# %%
# %pip install nbformat nbclient nbconvert
# %pip install -U numpy pymongo minio elasticsearch
# %pip install packaging
# Out:
# Requirement already satisfied: nbformat in c:\users\caiju\.conda\envs\dev\lib\site-packages (5.10.4)
# Requirement already satisfied: nbclient in c:\users\caiju\.conda\envs\dev\lib\site-packages (0.10.2)
# Requirement already satisfied: nbconvert in c:\users\caiju\.conda\envs\dev\lib\site-packages (7.16.6)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from nbclient) (8.6.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from nbconvert) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from bleach[css]!=5.0.0->nbconvert) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\caiju\.conda\envs\dev\lib\site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from nbconvert) (3.1.5)
# Requirement already satisfied: jupyterlab-pygments in c:\users\caiju\.conda\envs\dev\lib\site-packages (from nbconvert) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from nbconvert) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from nbconvert) (3.1.1)
# Requirement already satisfied: packaging in c:\users\caiju\.conda\envs\dev\lib\site-packages (from nbconvert) (24.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from nbconvert) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from nbconvert) (2.15.1)
# Requirement already satisfied: webencodings in c:\users\caiju\.conda\envs\dev\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from bleach[css]!=5.0.0->nbconvert) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from jsonschema>=2.6->nbformat) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from jsonschema>=2.6->nbformat) (0.22.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from jupyter-client>=6.1.12->nbclient) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from jupyter-client>=6.1.12->nbclient) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from jupyter-client>=6.1.12->nbclient) (6.4.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (308)
# Requirement already satisfied: typing-extensions in c:\users\caiju\.conda\envs\dev\lib\site-packages (from mistune<4,>=2.0.3->nbconvert) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from beautifulsoup4->nbconvert) (2.6)
# Requirement already satisfied: six>=1.5 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting numpy
#   Downloading numpy-2.2.2-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting pymongo
#   Downloading pymongo-4.11-cp310-cp310-win_amd64.whl.metadata (22 kB)
# Collecting minio
#   Downloading minio-7.2.15-py3-none-any.whl.metadata (6.7 kB)
# Collecting elasticsearch
#   Downloading elasticsearch-8.17.1-py3-none-any.whl.metadata (8.8 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: certifi in c:\users\caiju\.conda\envs\dev\lib\site-packages (from minio) (2025.1.31)
# Requirement already satisfied: urllib3 in c:\users\caiju\.conda\envs\dev\lib\site-packages (from minio) (2.3.0)
# Collecting argon2-cffi (from minio)
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pycryptodome in c:\users\caiju\.conda\envs\dev\lib\site-packages (from minio) (3.21.0)
# Requirement already satisfied: typing-extensions in c:\users\caiju\.conda\envs\dev\lib\site-packages (from minio) (4.12.2)
# Collecting elastic-transport<9,>=8.15.1 (from elasticsearch)
#   Downloading elastic_transport-8.17.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi->minio)
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi->minio)
#   Downloading cffi-1.17.1-cp310-cp310-win_amd64.whl.metadata (1.6 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Downloading numpy-2.2.2-cp310-cp310-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    -------- ------------------------------- 2.6/12.9 MB 18.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.9 MB 26.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 27.9 MB/s eta 0:00:00
# Downloading pymongo-4.11-cp310-cp310-win_amd64.whl (781 kB)
#    ---------------------------------------- 0.0/781.4 kB ? eta -:--:--
#    ---------------------------------------- 781.4/781.4 kB 5.5 MB/s eta 0:00:00
# Downloading minio-7.2.15-py3-none-any.whl (95 kB)
# Downloading elasticsearch-8.17.1-py3-none-any.whl (653 kB)
#    ---------------------------------------- 0.0/654.0 kB ? eta -:--:--
#    --------------------------------------- 654.0/654.0 kB 12.6 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Downloading elastic_transport-8.17.0-py3-none-any.whl (64 kB)
# Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Downloading cffi-1.17.1-cp310-cp310-win_amd64.whl (181 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: pycparser, numpy, elastic-transport, dnspython, pymongo, elasticsearch, cffi, argon2-cffi-bindings, argon2-cffi, minio
# Successfully installed argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 cffi-1.17.1 dnspython-2.7.0 elastic-transport-8.17.0 elasticsearch-8.17.1 minio-7.2.15 numpy-2.2.2 pycparser-2.22 pymongo-4.11
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: packaging in c:\users\caiju\.conda\envs\dev\lib\site-packages (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
DEBUG = True
TEST = True
from slines.utils.logging import init_logger
logger = init_logger(is_debug = DEBUG)

logger.info("This is an info message.")
logger.warning("This is a warning message.")
logger.error("This is an error message.")
# Out:
# SLINES_DIFY_API_PATH: /app/api does not exist.
# 2025-02-07 11:41:23,068 - slines.utils.logging - INFO - This is an info message.
# 2025-02-07 11:41:23,069 - slines.utils.logging - WARNING - This is a warning message.
# 2025-02-07 11:41:23,071 - slines.utils.logging - ERROR - This is an error message.

# %%
# dify_configs = {
#         "入库对象存储": {
#             "token": "app-g85zU05Oxcwex15EkAfr084N",
#             "entrypoint": "workflow",
#             "base_url": "http://192.168.1.244/v1",
#         }
# }
# from slines.modules.action import app_execute_mapping
# app_execute = app_execute_mapping.get("dify_workflow", None)
# app_execute
# config = dify_configs.get("入库对象存储")
# assert config is not None, "请检查配置是否正确"
# s3_dify_client = app_execute(config = config)
# 
# inputs = {
#     "samples": {
#         "source": "",
#         "target": ""
#     }
# }
# 
# TEST = True
# if TEST:
#     samples = inputs.copy()
#     samples["samples"]["source"] = "/app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市行政审批服务局关于三亚凤凰岛2#泊位港池维护性疏浚工程环境影响报告表的批复.docx"
#     samples["samples"]["target"] = "s3://Ui8HWTa4L9Ow7RU9zS2E:M8PLO52GH6NNJlQAStEV2NdT71pWbcEeDzdjTcqM@172.16.32.54:9000/swdocument"
#     result = s3_dify_client.execute(samples = samples)
#     print(result)
# 
# s3_dify_client

# %%
import os
from pathlib import Path
parent_path = f"Y:/电子公文库文档数据/分类前/公司爬取数据"
   
assert os.path.exists(parent_path), f"Path does not exist: {parent_path}"

# %%
from slines.snow_id import get_snow_id
try:
    uid = get_snow_id()
    logger.info(f"Successfully generated snowflake ID: {uid}")
except Exception as e:
    logger.error(f"Failed to generate snowflake ID: {e}")

uid
# Out:
# 2025-02-07 13:32:15,805 - slines.utils.logging - INFO - Successfully generated snowflake ID: 196964916343430
# 196964916343430

# %%
import json
from pymongo import MongoClient

mongo_url = r"mongodb://root:Suwell123@172.16.32.201:27017/"

def mongo_query(mongo_url = None, collection = None, query = {}):
    site_names = []
    
    try:
        if (collection is None):
            mongo_client = MongoClient(mongo_url)
        
            db = mongo_client['crawler_file']
            collection = db['file_info']
        
            result = collection.distinct("SiteName", filter=query)
        else:
            result = collection.find(query)

    except Exception as e:
        logger.error(f"An error occurred: {e}")
        return None, []

    return collection, result

query = {"SiteName": {"$ne": None}}
collection, site_names = mongo_query(mongo_url = mongo_url, query = query)

logger.info(f"站点总数: {len(site_names)}, 站点名称: {site_names}")
# Out:
# 2025-02-07 13:32:25,937 - slines.utils.logging - INFO - 站点总数: 596, 站点名称: ['《求是》杂志', '三亚市人民政府', '三明市人民政府', '三门峡市人民政府', '上海人大', '上海发布', '上海市人民政府', '上海市嘉定区人民政府', '上海市奉贤区人民政府', '上海市宝山区人民政府', '上海市崇明区人民政府', '上海市徐汇区人民政府', '上海市普陀区人民政府', '上海市杨浦区人民政府', '上海市松江区人民政府', '上海市浦东新区人民政府', '上海市虹口区人民政府', '上海市金山区人民政府', '上海市长宁区人民政府', '上海市青浦区人民政府', '上海市静安区人民政府', '上海市黄浦区人民政府', '上海政协', '上饶市人民政府', '世界环境', '东莞市人民政府', '东营市人民政府', '东风汽车集团有限公司', '中共上海市纪律检查委员会', '中共中央台湾工作办公室、国务院台湾事务办公室', '中共云南省纪律检查委员会', '中共内蒙古自治区纪律检查委员会', '中共北京市海淀区纪律检查委员会', '中共北京市纪律检查委员会', '中共吉林省纪律检查委员会', '中共四川省纪律检查委员会', '中共天津市纪律检查委员会', '中共宁夏回族自治区纪律检查委员会', '中共安徽省纪律检查委员会', '中共山东省纪律检查委员会', '中共山西省纪律检查委员会', '中共广东省纪律检查委员会', '中共广西壮族自治区纪律检查委员会', '中共新疆生产建设兵团纪律检查委员会', '中共新疆维吾尔自治区纪律检查委员会', '中共江苏省纪律检查委员会', '中共江西省纪律检查委员会', '中共河北省纪律检查委员会', '中共河南省纪律检查委员会', '中共浙江省纪律检查委员会', '中共海南省纪律检查委员会', '中共湖北省纪律检查委员会', '中共湖南省纪律检查委员会', '中共甘肃省纪律检查委员会', '中共福建省纪律检查委员会', '中共西藏自治区纪律检查委员会', '中共贵州省纪律检查委员会', '中共辽宁省纪律检查委员会', '中共重庆市纪律检查委员会', '中共陕西省纪律检查委员会', '中共青海省纪律检查委员会', '中共黑龙江省纪律检查委员会', '中华人民共和国中央人民政府', '中华人民共和国交通运输部', '中华人民共和国人力资源和社会保障部', '中华人民共和国住房和城乡建设部', '中华人民共和国公安部', '中华人民共和国农业农村部', '中华人民共和国卫生健康委员会', '中华人民共和国司法部', '中华人民共和国商务部', '中华人民共和国国家互联网信息办公室', '中华人民共和国国家卫生健康委员会', '中华人民共和国国家发展和改革委员会', '中华人民共和国国家发展改革委员会', '中华人民共和国国家民族事务委员会', '中华人民共和国国家监察委员会', '中华人民共和国国家邮政局', '中华人民共和国国防部', '中华人民共和国审计署', '中华人民共和国工业和信息化部', '中华人民共和国工业和信息化部政务服务平台', '中华人民共和国应急管理部', '中华人民共和国教育部', '中华人民共和国文化和旅游部', '中华人民共和国最高人民检察院', '中华人民共和国最高人民法院', '中华人民共和国民政部', '中华人民共和国水利部', '中华人民共和国海关总署', '中华人民共和国生态环境部', '中华人民共和国科学技术部', '中华人民共和国自然能资源部', '中华人民共和国自然资源部', '中华人民共和国财政部', '中华人民共和国退役军人事务部', '中国·深圳政府采购', '中国一重集团有限公司', '中国东方电气集团有限公司', '中国五矿集团有限公司', '中国人民共和国中央人民政府', '中国人民政治协商会议全国委员会', '中国人民政治协商会议江苏省苏州市委员会', '中国人民银行', '中国共产党新闻网', '中国兵器工业集团有限公司', '中国兵器装备集团有限公司', '中国军网', '中国南方航空集团有限公司', '中国国际工程咨询有限公司', '中国政府网', '中国政府采购网', '中国机械工业集团有限公司', '中国核工业集团有限公司', '中国民用航空局', '中国气象局', '中国法院网', '中国海洋石油集团有限公司', '中国版权保护中心', '中国版权服务', '中国环境', '中国环境宣传教育', '中国环境科学研究院', '中国生态环境信息化', '中国电信集团有限公司', '中国电子信息产业集团有限公司', '中国电子科技集团有限公司', '中国石油天然气集团有限公司', '中国社会科学词条库', '中国科学院', '中国科学院生态环境研究中心', '中国第一汽车集团有限公司', '中国红色文化党建网', '中国联合网络通信集团有限公司', '中国航天科工集团有限公司', '中国航天科技集团有限公司', '中国航空发动机集团有限公司', '中国航空工业集团有限公司', '中国航空集团有限公司', '中国船舶集团有限公司', '中国融通资产管理集团有限公司', '中国裁判文书网', '中国证券监督管理委员会', '中国铝业集团有限公司', '中国青年网', '中央纪委国家监委', '中山市人民政府', '中新网', '临汾市人民政府', '丹东市人民政府', '丽水市人民政府', '乌鲁木齐市人民政府', '乐清市人民政府', '九江市人民政府', '习近平系列重要讲话数据库', '云南省人民政府', '云浮市人民政府', '交通运输部', '亳州市人民政府', '人民日报写作课', '人民日报评论', '人民网', '人民网评论', '人民论坛网', '今日浙江', '伊宁市人民政府', '伊春市人民政府', '伊犁哈萨克自治州人民政府', '住房城乡建设部', '佛山市人民政府', '保定市人民政府', '修水县人民政府', '先锋成都', '克孜勒苏柯尔克孜自治州人民政府', '克拉玛依市人民政府', '党史学习教育', '党建网', '党建网微平台', '党建资讯', '党报头版要闻', '全国人民代表大会常务委员会', '公文搜网', '公选王遴选网', '六安市人民政府', '六安市金安区人民政府', '兰溪市人民政府', '共产党员网', '冀时办', '内蒙古发展改革委', '内蒙古自治区人民政府', '内蒙古自治区国营索伦牧场', '农业农村部', '农业农村部兽药评审中心', '决策杂志', '办公室学问', '包头市人民政府', '北京市东城区人民政府', '北京市丰台区人民政府', '北京市人民政府', '北京市大兴区人民政府', '北京市密云区人民政府', '北京市平谷区人民政府', '北京市延庆区人民政府', '北京市怀柔区人民政府', '北京市房山区人民代表大会常务委员会', '北京市房山区人民政府', '北京市昌平区人民政府', '北京市朝阳区人民政府', '北京市海淀区人民政府', '北京市石景山区人民政府', '北京市西城区人民政府', '北京市通州区人民代表大会', '北京市通州区人民政府', '北京市门头沟区人民政府', '北京市顺义区人民政府', '北海市人民政府', '十堰市人民政府', '华侨城集团有限公司', '南京市人民政府', '南京市公安局', '南京市玄武区人民政府', '南宁市人民政府', '南平市人民政府', '南昌市人民政府', '南通市人民政府', '南阳市人民政府', '博尔塔拉蒙古自治州人民政府', '博特妙笔', '印江土家族苗族自治县人民政府', '台州市人民政府', '合肥市人民政府', '吉安市人民政府', '吉林市人民政府', '吉林省人民政府', '吐鲁番市人民政府', '吕梁市人民政府', '周口市人民政府', '呼和浩特市人民政府', '和田地区行政公署', '哈密市人民政府', '哈尔滨市人民政府', '哈尔滨电气集团有限公司', '商丘市人民政府', '商务部', '喀什地区人民政府', '嘉兴市人民政府', '四川党校报', '四川党的建设', '四川省人民政府', '四平市人民政府', '国务院发展研究中心', '国务院台湾事务办公室', '国务院国有资产监督管理委员会', '国家中医药局', '国家互联网信息办公室', '国家体育总局', '国家信访局', '国家卫生健康委员会', '国家发展和改革委员会', '国家国防科技工业局', '国家外汇管理局', '国家宗教事务局', '国家工业信息安全发展研究中心', '国家市场监督管理总局', '国家广播电视总局', '国家数据局', '国家文物局', '国家新闻出版署', '国家新闻出版署（国家版权局）', '国家机关事务管理局', '国家林业和草原局', '国家核安全局', '国家民族事务委员会', '国家气候战略中心', '国家法律法规数据库', '国家烟草专卖局', '国家版权局', '国家知识产权局', '国家石油天然气管网集团有限公司', '国家移民管理局', '国家税务总局', '国家税务总局深圳市税务局', '国家粮食和物资储备局', '国家统计局', '国家能源局', '国家能源投资集团有限责任公司', '国家药品监督管理局', '国家认证认可监督管理委员会', '国家金融监督管理总局', '国家铁路局',  ...

# %%
from slinesplug.plugins.data_storage.storage import StorageClient
from slines.utils.utils import get_str_hash

minio_url = r"s3://Ui8HWTa4L9Ow7RU9zS2E:M8PLO52GH6NNJlQAStEV2NdT71pWbcEeDzdjTcqM@172.16.32.54:9000/swdocument"

if DEBUG:
    minio_url = minio_url + "-test"

try:
    target_client = StorageClient.get_client(minio_url)
    assert target_client is not None
    logger.info("Successfully created StorageClient.")
except Exception as e:
    logger.error(f"Failed to create StorageClient: {e}")

def upload_file(webSite, filePath, fileId, target_path = minio_url, os_id = None):
    if (os_id is not None):
        logger.info(f"File already uploaded: {os_id}")
        return os_id

    file_path = filePath.replace('\\', '/')
    full_path = os.path.join(parent_path, file_path)

    result = None
    if os.path.exists(full_path):
        try:
            object_name = webSite + '/' + get_str_hash(file_path)[:10] + '/' +str(fileId)

            logger.info(f"upload file: {full_path} to {target_path} as {object_name}")
            result = target_client.put(source=full_path, target=target_path, key=object_name)
            logger.info(f"File uploaded successfully: {full_path} to {target_path} as {object_name}")
        except Exception as e:
            logger.error(f"Failed to upload file: {full_path}. Error: {str(e)}")
    else:
        result = f"File does not exist: {full_path}"
        logger.error(result)
        
    return result

# if TEST:
#     target_client.list(minio_url)
# 
#     from slinesplug.plugins.data_storage.storage import StorageClient
#     full_path = r"/app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市行政审批服务局关于三亚凤凰岛2#泊位港池维护性疏浚工程环境影响报告表的批复.docx"
# 
#     FileId = get_snow_id()
# 
#     if os.path.exists(full_path):
#         try:
#             object_name = str(FileId)
#             result = target_client.put(str(full_path), minio_url, FileId)
# 
#             logger.info(f"File uploaded successfully: {full_path} to {minio_url} as {object_name}")
#         except Exception as e:
#             result = f"Failed to upload file: {full_path}. Error: {str(e)}"
#             logger.error(result)
#     else:
#         result = f"File does not exist: {full_path}"
#         logger.error(result)
# 
#     print(result)
# Out:
# 2025-02-07 13:32:31,744 - slines.utils.logging - INFO - Successfully created StorageClient.

# %%
from slines.utils.utils import get_str_hash

parent_path_hash = get_str_hash(parent_path)
parent_path_hash
# Out:
# '593e1f34af7a86c37cfd646227f1fcb440a6646251e9305e5174f699dd11bdde'

# %%
from slinesplug.plugins.elasticsearch_manager.builtin.esmanager.esmanager import ESManager
from slinesplug.plugins.elasticsearch_manager.builtin.esmanager.data_collection import dc_index_name, dc_document, dc_paragraph
from urllib.parse import urlparse

es_url = r"http://elastic:Suwell123@172.16.32.54:9200"

if DEBUG:
    dc_index_name = dc_index_name + "-test"

print(dc_index_name)
# Out:
# 2025-01-07 07:37:31,340 - slines.utils.logging - INFO - Successfully created index: swdocument-test

# %%
import os
import copy
from datetime import datetime

def get_path(filename, parent_path=parent_path):
    filename = filename.replace('\\', '/')
    return filename # os.path.join(parent_path, filename)

def get_file_id(FileId):
    if FileId is None:
        return get_snow_id()
    return FileId

def get_status(GeneratedJson=None):
    if GeneratedJson is None:
        return 0
    return 1

def get_accessoryList(filename = "", Accessory=[]):
    filepath = os.path.dirname(filename.replace('\\', '/'))
    for i in range(len(Accessory)):
        Accessory[i] = os.path.join(filepath, Accessory[i])
    
    return Accessory

def get_attachmentList(Attachment=[]):
    if not Attachment or isinstance(Attachment, bool):
        return []
    
    if isinstance(Attachment, dict):
        return [Attachment]
    
    return Attachment
    
def convert_date_to_timestamp(date_str):
    if date_str is None:
        return date_str

    date_formats = [
        "%Y-%m-%dT%H:%M:%S.%f",
        "%Y-%m-%dT%H:%M:%S",
        "%Y-%m-%d %H:%M:%S",
        "%Y/%m/%d %H:%M:%S",
        "%d-%m-%Y",
        "%m/%d/%Y",
        "%Y.%m.%d",
        # Add more formats as needed
    ]

    for fmt in date_formats:
        try:
            dt = datetime.strptime(date_str, fmt)
            timestamp = int(dt.timestamp() * 1000)  # Convert to milliseconds
            return timestamp
        except ValueError:
            continue

    logger.error(f"Unrecognized date format: {date_str}")
    return None
    
migrations_v2 = {
    "ver": "2",
    "iteration_ver": "2.1.1.9",
    "iteration_description": "更新V2格式数据",
    "changes": {
        "modified": {
            "fileId": {
                "type": "string",
                "description": "文件唯一ID",
                "action": {
                    "type": "function",
                    "entrypoint": get_file_id,
                    "kwargs": {
                        "FileId": "FileId"
                    }
                }
            },
            "filePath": {
                "type": "string",
                "description": "NAS路径",
                "action": {
                    "type": "function",
                    "entrypoint": get_path,
                    "kwargs": {
                        "filename": "FileName"
                    }
                }
            },
            "webSite": {
                "type": "string",
                "description": "网站",
                "action": {
                    "type": "transfer",
                    "source": "SiteName"
                }
            },
            "os_id": {
                "type": "string",
                "description": "上传到对象存储",
                "action": {
                    "type": "function",
                    "entrypoint": upload_file,
                    "kwargs": {
                        "filePath": "filePath",
                        "webSite": "webSite",
                        "fileId": "fileId",
                        "os_id": "os_id"
                    }
                }
            },
            "status": {
                "type": "string",
                "description": "入库状态",
                "action": {
                    "type": "function",
                    "entrypoint": get_status,
                    "kwargs": {
                        "GeneratedJson": "GeneratedJson"
                    }
                }
            },
            "isFormatted": {
                "type": "string",
                "description": "是否格式化",
                "action": {
                    "type": "function",
                    "entrypoint": get_status,
                    "kwargs": {
                        "GeneratedJson": "GeneratedJson"
                    }
                }
            },
            "oldID": {
                "type": "string",
                "description": "老的ID",
                "action": {
                    "type": "transfer",
                    "source": "_id"
                }
            },
            "srcUrl": {
                "type": "string",
                "description": "原始链接",
                "action": {
                    "type": "transfer",
                    "source": "Url"
                }
            },
            "categoryList": {
                "type": "string",
                "description": "类别列表",
                "action": {
                    "type": "transfer",
                    "source": "Category"
                }
            },
            "title": {
                "type": "string",
                "description": "标题",
                "action": {
                    "type": "transfer",
                    "source": "Title"
                }
            },
            "releaseDate": {
                "type": "string",
                "description": "发布日期|公布日期",
                "action": {
                    "type": "function",
                    "entrypoint": convert_date_to_timestamp,
                    "kwargs": {
                        "date_str": "FileDate"
                    }
                }
            },
            "keywordList": {
                "type": "string",
                "description": "关键词列表",
                "action": {
                    "type": "transfer",
                    "source": "Keywords"
                }
            },
            "issuer": {
                "type": "string",
                "description": "发文机关",
                "action": {
                    "type": "transfer",
                    "source": "Issuer"
                }
            },
            "issueNo": {
                "type": "string",
                "description": "发文字号",
                "action": {
                    "type": "transfer",
                    "source": "FileNo"
                }
            },
            "crawlTime": {
                "type": "string",
                "description": "爬取时间",
                "action": {
                    "type": "function",
                    "entrypoint": convert_date_to_timestamp,
                    "kwargs": {
                        "date_str": "CrawlTime"
                    }
                }
            },
            "repositoryList": {
                "type": "string",
                "description": "文档类型",
                "action": {
                    "type": "transfer",
                    "source": "type_name"
                }
            },
            "levelTypeList": {
                "type": "string",
                "description": "发文机关标签",
                "action": {
                    "type": "transfer",
                    "source": "level_type_list"
                }
            },
            "accessoryList": {
                "type": "string",
                "description": "附件列表",
                "action": {
                    "type": "function",
                    "entrypoint": get_accessoryList,
                    "kwargs": {
                        "Accessory": "Accessory",
                        "filename": "FileName"
                    }
                }
            },
            "attachmentList": {
                "type": "string",
                "description": "附件列表",
                "action": {
                    "type": "function",
                    "entrypoint": get_attachmentList,
                    "kwargs": {
                        "Attachment": "Attachment",
                    }
                }
            }
        },
        "removed": {
            "FileId": {
                "type": "string",
                "description": "FileId"
            },
            "SiteName": {
                "type": "string",
                "description": "SiteName"
            },
            "Accessory": {
                "type": "string",
                "description": "Accessory"
            },
            "FileDate": {
                "type": "string",
                "description": "FileDate"
            },
            "CrawlTime": {
                "type": "string",
                "description": "CrawlTime"
            },
            "Attachment": {
                "type": "string",
                "description": "Attachment"
            },
            "Status": {
                "type": "string",
                "description": "删除旧的Status字段"
            },
            "GeneratedJson": {
                "type": "string",
                "description": "删除旧的GeneratedJson字段"
            },
            "FileName": {
                "type": "string",
                "description": "FileName"
            },
            "verson": {
                "type": "string",
                "description": "verson"
            },
            "Batch": {
                "type": "string",
                "description": "Batch"
            },
        }
    }
}

# %%
class MigrationProcessor:

    @staticmethod
    def migrations(data, migrations):
        if migrations is None:
            return None

        samples = data.copy()
        logger.info(f'Processing file: {samples.get("FileName")}')

        modifieds = migrations.get("modified")
        if modifieds is not None:    
            for key, value in modifieds.items():
                action = value.get("action")
                description = value.get("description")

                if action.get("type") == "transfer":
                    source = action.get("source")
                    old_value = samples.get(source)

                    samples[key] = samples.pop(source, None)

                elif action.get("type") == "function":
                    entrypoint = action.get("entrypoint")
                    kwargs = action.get("kwargs").copy()

                    for k, v in kwargs.items():                    
                        if isinstance(v, str) and v in samples:
                            kwargs[k] = samples.get(v, None)
                        else:
                            kwargs[k] = None

                    old_value = copy.deepcopy(kwargs)
                    samples[key] = entrypoint(**kwargs)

                new_value = samples[key]
                logger.info(f"Executing modified script {key} {old_value} -> {new_value}")

        removeds = migrations.get("removed")
        if removeds is not None:    
            for key, value in removeds.items():
                if DEBUG:
                    logger.info(f"Executing remove script: {key} - {value.get('description')}")
                samples.pop(key, None)

        return samples

    def __init__(self, migrations_info):
        self.migrations_info = {}
        if isinstance(migrations_info, dict):
            self.migrations_info = migrations_info
        elif isinstance(migrations_info, str):
            if os.path.isfile(migrations_info):
                if migrations_info.lower().endswith('.json'):
                    with open(migrations_info, 'r', encoding='utf-8') as file:
                        self.migrations_info = json.load(file)
                else:
                    logger.error("Unsupported file format. Only JSON files are supported.")
            else:
                try:
                    self.migrations_info = json.loads(migrations_info)
                except json.JSONDecodeError:
                    logger.error("Invalid JSON string provided for migrations_info.")
        else:
            logger.error("migrations_info must be a dict, a JSON string, or a file path.")

    def process(self, data):
        return MigrationProcessor.migrations(data, self.migrations_info.get("changes"))

if TEST:
    # test_data = {'_id': '665057384726e81ab0707ab9', 'Url': 'http://ny.sanya.gov.cn/nyjsite/bmwjxx/202405/c6807a11a1f24dc6832406f74d8cbd74.shtml', 'Title': '三亚农业产业投资指南', 'FileName': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\三亚农业产业投资指南.docx', 'RawFile': 'None', 'SiteName': '三亚市人民政府', 'Category': ['政策', '政府信息公开专栏', '政策文件', '部门文件'], 'CrawlTime': '2024-05-24T17:00:33.343000', 'FileDate': '2024.05.23', 'Keywords': [], 'Issuer': '三亚市农业农村局', 'FileNo': '', 'Accessory': ['三亚农业产业投资指南（印刷版）.pdf'], 'Stored': False, 'verson': '0.1', 'Batch': '1716541233', 'Extend': {'regulation': {'source': '三亚市农业农村局', 'time': '2024.05.23'}}, 'WrittenDate': '2024.05.23', 'Status': '有效', 'FileId': 105357478397830}
    test_data = {'_id': '6650615d4726e81ab0707f92', 'Url': 'http://hrss.sanya.gov.cn/rsjsite/bmwjxx/202212/7b813c5788524a218ac24b5578e7a820.shtml', 'Title': '三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知', 'FileName': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\劳动、人事、监察;\\三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知.docx', 'RawFile': 'None', 'SiteName': '三亚市人民政府', 'Category': ['政策', '政府信息公开专栏', '政策文件', '部门文件', '劳动、人事、监察;'], 'CrawlTime': '2024-05-24T17:43:54.821000', 'FileDate': '2022.12.23', 'Keywords': [], 'Issuer': '三亚市人力资源和社会保障局', 'FileNo': '三人社发〔2022〕146号', 'Accessory': ['1.海南省用人单位劳动保障年度书面审查报审表.doc', '2.书面审查报审表填报说明.doc', '3.用人单位职工名册.doc', '4.市、区人力资源和社会保障局联系人及联系方式.docx'], 'Stored': False, 'verson': '0.1', 'Batch': '1716543834', 'Extend': {'regulation': {'source': '三亚市人力资源和社会保障局', 'time': '2022.12.23'}, 'Policy': {'Type': ['省市级', '海南省', '三亚市'], 'Issuer': '三亚市人力资源和社会保障局', 'Theme': [], 'FileFate': '2022.12.23', 'Genre': '通知'}}, 'WrittenDate': '2022.12.21', 'Status': '有效', 'FileId': 105368115321670, 'Attachment': True}

    print(f"old: {test_data}")

    mp = MigrationProcessor(migrations_v2)
    new_data = mp.process(test_data)

    print(f"new: {new_data}")

    result = updata_es(es, new_data, id = new_data["fileId"], index_name=dc_index_name)
    print(result)
# Out:
# 2025-01-07 07:37:42,196 - slines.utils.logging - INFO - Processing file: 三亚市人民政府\政策\政府信息公开专栏\政策文件\部门文件\劳动、人事、监察;\三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知.docx
# 2025-01-07 07:37:42,198 - slines.utils.logging - INFO - Executing modified script fileId {'FileId': 105368115321670} -> 105368115321670
# 2025-01-07 07:37:42,198 - slines.utils.logging - INFO - Executing modified script filePath {'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\劳动、人事、监察;\\三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知.docx'} -> 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/劳动、人事、监察;/三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知.docx
# 2025-01-07 07:37:42,199 - slines.utils.logging - INFO - Executing modified script webSite 三亚市人民政府 -> 三亚市人民政府
# old: {'_id': '6650615d4726e81ab0707f92', 'Url': 'http://hrss.sanya.gov.cn/rsjsite/bmwjxx/202212/7b813c5788524a218ac24b5578e7a820.shtml', 'Title': '三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知', 'FileName': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\劳动、人事、监察;\\三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知.docx', 'RawFile': 'None', 'SiteName': '三亚市人民政府', 'Category': ['政策', '政府信息公开专栏', '政策文件', '部门文件', '劳动、人事、监察;'], 'CrawlTime': '2024-05-24T17:43:54.821000', 'FileDate': '2022.12.23', 'Keywords': [], 'Issuer': '三亚市人力资源和社会保障局', 'FileNo': '三人社发〔2022〕146号', 'Accessory': ['1.海南省用人单位劳动保障年度书面审查报审表.doc', '2.书面审查报审表填报说明.doc', '3.用人单位职工名册.doc', '4.市、区人力资源和社会保障局联系人及联系方式.docx'], 'Stored': False, 'verson': '0.1', 'Batch': '1716543834', 'Extend': {'regulation': {'source': '三亚市人力资源和社会保障局', 'time': '2022.12.23'}, 'Policy': {'Type': ['省市级', '海南省', '三亚市'], 'Issuer': '三亚市人力资源和社会保障局', 'Theme': [], 'FileFate': '2022.12.23', 'Genre': '通知'}}, 'WrittenDate': '2022.12.21', 'Status': '有效', 'FileId': 105368115321670, 'Attachment': True}
# 2025-01-07 07:37:42,833 - slines.utils.logging - INFO - upload file: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/劳动、人事、监察;/三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知.docx to s3://Ui8HWTa4L9Ow7RU9zS2E:M8PLO52GH6NNJlQAStEV2NdT71pWbcEeDzdjTcqM@172.16.32.54:9000/swdocument-test as 三亚市人民政府/1d3d4bdbc0/105368115321670
# 2025-01-07 07:37:43,615 - slines.utils.logging - INFO - File uploaded successfully: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/劳动、人事、监察;/三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知.docx to s3://Ui8HWTa4L9Ow7RU9zS2E:M8PLO52GH6NNJlQAStEV2NdT71pWbcEeDzdjTcqM@172.16.32.54:9000/swdocument-test as 三亚市人民政府/1d3d4bdbc0/105368115321670
# 2025-01-07 07:37:43,615 - slines.utils.logging - INFO - Executing modified script os_id {'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/劳动、人事、监察;/三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知.docx', 'webSite': '三亚市人民政府', 'fileId': 105368115321670, 'os_id': None} -> 三亚市人民政府/1d3d4bdbc0/105368115321670
# 2025-01-07 07:37:43,616 - slines.utils.logging - INFO - Executing modified script status {'GeneratedJson': None} -> 0
# 2025-01-07 07:37:43,617 - slines.utils.logging - INFO - Executing modified script isFormatted {'GeneratedJson': None} -> 0
# 2025-01-07 07:37:43,618 - slines.utils.logging - INFO - Executing modified script oldID 6650615d4726e81ab0707f92 -> 6650615d4726e81ab0707f92
# 2025-01-07 07:37:43,618 - slines.utils.logging - INFO - Executing modified script srcUrl http://hrss.sanya.gov.cn/rsjsite/bmwjxx/202212/7b813c5788524a218ac24b5578e7a820.shtml -> http://hrss.sanya.gov.cn/rsjsite/bmwjxx/202212/7b813c5788524a218ac24b5578e7a820.shtml
# 2025-01-07 07:37:43,618 - slines.utils.logging - INFO - Executing modified script categoryList ['政策', '政府信息公开专栏', '政策文件', '部门文件', '劳动、人事、监察;'] -> ['政策', '政府信息公开专栏', '政策文件', '部门文件', '劳动、人事、监察;']
# 2025-01-07 07:37:43,619 - slines.utils.logging - INFO - Executing modified script title 三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知 -> 三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知
# 2025-01-07 07:37:43,621 - slines.utils.logging - INFO - Executing modified script releaseDate {'date_str': '2022.12.23'} -> 1671753600000
# 2025-01-07 07:37:43,622 - slines.utils.logging - INFO - Executing modified script keywordList [] -> []
# 2025-01-07 07:37:43,622 - slines.utils.logging - INFO - Executing modified script issuer 三亚市人力资源和社会保障局 -> 三亚市人力资源和社会保障局
# 2025-01-07 07:37:43,622 - slines.utils.logging - INFO - Executing modified script issueNo 三人社发〔2022〕146号 -> 三人社发〔2022〕146号
# 2025-01-07 07:37:43,623 - slines.utils.logging - INFO - Executing modified script crawlTime {'date_str': '2024-05-24T17:43:54.821000'} -> 1716572634821
# 2025-01-07 07:37:43,623 - slines.utils.logging - INFO - Executing modified script repositoryList None -> None
# 2025-01-07 07:37:43,623 - slines.utils.logging - INFO - Executing modified script levelTypeList None -> None
# 2025-01-07 07:37:43,624 - slines.utils.logging - INFO - Executing modified script accessoryList {'Accessory': ['1.海南省用人单位劳动保障年度书面审查报审表.doc', '2.书面审查报审表填报说明.doc', '3.用人单位职工名册.doc', '4.市、区人力资源和社会保障局联系人及联系方式.docx'], 'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\劳动、人事、监察;\\三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知.docx'} -> ['三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/劳动、人事、监察;/1.海南省用人单位劳动保障年度书面审查报审表.doc', '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/劳动、人事、监察;/2.书面审查报审表填报说明.doc', '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/劳动、人事、监察;/3.用人单位职工名册.doc', '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/劳动、人事、监察;/4.市、区人力资源和社会保障局联系人及联系方式.docx']
# 2025-01-07 07:37:43,624 - slines.utils.logging - INFO - Executing modified script attachmentList {'Attachment': True} -> []
# 2025-01-07 07:37:43,625 - slines.utils.logging - INFO - Executing remove script: FileId - FileId
# 2025-01-07 07:37:43,626 - slines.utils.logging - INFO - Executing remove script: SiteName - SiteName
# 2025-01-07 07:37:43,626 - slines.utils.logging - INFO - Executing remove script: Accessory - Accessory
# 2025-01-07 07:37:43,627 - slines.utils.logging - INFO - Executing remove script: FileDate - FileDate
# 2025-01-07 07:37:43,627 - slines.utils.logging - INFO - Executing remove script: CrawlTime - CrawlTime
# 2025-01-07 07:37:43,627 - slines.utils.logging - INFO - Executing remove script: Attachment - Attachment
# 2025-01-07 07:37:43,628 - slines.utils.logging - INFO - Executing remove script: Status - 删除旧的Status字段
# 2025-01-07 07:37:43,628 - slines.utils.logging - INFO - Executing remove script: GeneratedJson - 删除旧的GeneratedJson字段
# 2025-01-07 07:37:43,629 - slines.utils.logging - INFO - Executing remove script: FileName - FileName
# 2025-01-07 07:37:43,630 - slines.utils.logging - INFO - Executing remove script: verson - verson
# 2025-01-07 07:37:43,630 - slines.utils.logging - INFO - Executing remove script: Batch - Batch
# new: {'RawFile': 'None', 'Stored': False, 'Extend': {'regulation': {'source': '三亚市人力资源和社会保障局', 'time': '2022.12.23'}, 'Policy': {'Type': ['省市级', '海南省', '三亚市'], 'Issuer': '三亚市人力资源和社会保障局', 'Theme': [], 'FileFate': '2022.12.23', 'Genre': '通知'}}, 'WrittenDate': '2022.12.21', 'fileId': 105368115321670, 'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/劳动、人事、监察;/三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知.docx', 'webSite': '三亚市人民政府', 'os_id': '三亚市人民政府/1d3d4bdbc0/105368115321670', 'status': 0, 'isFormatted': 0, 'oldID': '6650615d4726e81ab0707f92', 'srcUrl': 'http://hrss.sanya.gov.cn/rsjsite/bmwjxx/202212/7b813c5788524a218ac24b5578e7a820.shtml', 'categoryList': ['政策', '政府信息公开专栏', '政策文件', '部门文件', '劳动、人事、监察;'], 'title': '三亚市人力资源和社会保障局关于开展2022年度劳动保障书面审查工作的通知', 'releaseDate': 1671753600000, 'keywordList': [], 'issuer': '三亚市人力资源和社会保障局', 'issueNo': '三人社发〔2022〕146号', 'crawlTime': 1716572634821, 'repositoryList': None, 'levelTypeList': None, 'accessoryList': ['三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/劳动、人事、监察;/1.海南省用人单位劳动保障年度书面审查报审表.doc', '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/劳动、人事、监察;/2.书面审查报审表填报说明.doc', '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/劳动、人事、监察;/3.用人单位职工名册.doc', '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/劳动、人事、监察;/4.市、区人力资源和社会保障局联系人及联系方式.docx'], 'attachmentList': []}
# 105368115321670

# %%
from packaging import version

# macos: mount_smbfs 'smb://bot:bot123456@172.16.32.217/Test' ~/remote_data ## umount ~/remote_data
# linux：mount -t cifs bot:bot123456@172.16.32.217/Test ~/remote_data -o nobrowse

site_number = 0
processed_count = 0

logger.info(f"站点总数: {len(site_names)}")
if DEBUG:
    site_names = [site_names[0]]

success_count = 0
failure_count = 0

def serialize_document(doc):
    if isinstance(doc, dict):
        return {key: serialize_document(value) for key, value in doc.items()}
    elif isinstance(doc, list):
        return [serialize_document(item) for item in doc]
    elif isinstance(doc, (int, float, str, bool)):
        return doc
    elif hasattr(doc, 'isoformat'):
        return doc.isoformat()
    elif hasattr(doc, 'binary'):
        return doc.binary.hex()
    else:
        return str(doc)   

def version_analysis(existing_data, new_data):
    existing_version = version.parse(existing_data.get('iteration_ver', '0'))
    new_version = version.parse(migrations_data.get('iteration_ver', '0'))
    if new_version <= existing_version:
        logger.info(f"Skipping migration for {full_path}: existing version {existing_version} >= new version {new_version}")
        return False
    return True

def docdata_processor(doc_data, migrations_data):
    _data = MigrationProcessor.migrations(doc_data, migrations_data["changes"])
    if _data is None:
        logger.error(f"Failed to process data for {doc_data.get('fileId')}")

    _data["migrations_ver"] = ver
    _data["iteration_ver"] = migrations_data.get('iteration_ver', ver)
    _data["iteration_description"] = migrations_data.get('iteration_description', ver)

    es_id = updata_es(es, _data, str(_data["fileId"]), dc_index_name)
    if es_id is None:
        logger.error(f"Failed to update ES for {_data.get('fileId')}")

    new_doc_data = {
            "file_id": doc_data.get('FileId', None),
            "es_id": es_id,
            "os_id": _data.get("os_id", None),
            "src_url": _data.get('srcUrl', ''),
            "file_path": _data.get('filePath', ''),
            "ver": ver,
            "Ver1": doc_data,
            f"Ver{ver}": _data
        }
    return new_doc_data

for site_name in site_names:

    if DEBUG and site_number > 1:
        break

    site_number += 1
    try:
        if site_name is None:
            continue

        query = {"SiteName": site_name}
        _, site_data = mongo_query(collection = collection, query = query)
        site_data = list(site_data)

        logger.info(f"开始转换: {site_name} ({site_number}/{len(site_names)}) 数据量: {len(site_data)} ")
        
        success_count = 0
        failure_count = 0
        
        number = 0
        for data in site_data:
            if DEBUG and number > 100:
                break
            number = number + 1
            
            try:
                doc_data = serialize_document(data)
                File_Name = doc_data.get('FileName', '').replace('\\', '/')
                if not File_Name or File_Name == '':
                    continue

                full_path = os.path.join(parent_path, File_Name)
                if os.path.exists(full_path):
                    if DEBUG:
                        logger.info(f"File exists: {full_path}")
                else:
                    logger.error(f"File does not exist: {full_path}")
                    continue

                migrations_data = migrations_v2.copy()
                ver = migrations_data.get('ver', '2')
                json_path = full_path + '.json'
                
                if os.path.exists(json_path): # and DEBUG == False:
                    try:
                        with open(json_path, 'r') as f:
                            existing_data = json.load(f)
                        have_update = version_analysis(existing_data, migrations_data)
                        if not have_update:
                            continue
                        doc_data["os_id"] = existing_data.get('os_id', None)
                    except json.JSONDecodeError as e:
                        logger.error(f"JSON decode error for {json_path}: {e}")
                    except Exception as e:
                        logger.error(f"Error processing JSON for {json_path}: {e}")

                new_doc_data = docdata_processor(doc_data, migrations_data)
                logger.info(f'file_id: {new_doc_data.get("file_id")}, file_path: {new_doc_data.get("file_path")}')
                
                with open(json_path, 'w', encoding='utf-8') as json_file:
                    json.dump(new_doc_data, json_file, ensure_ascii=False, indent=4)
                                
                processed_count += 1
                success_count += 1

            except Exception as e:
                logger.error(f"An error occurred: {e}")
                failure_count += 1

            if processed_count % 1000 == 0:
                print(f"Processed {processed_count} files, Success: {success_count}, Failure: {failure_count}")

    except Exception as e:
        logger.error(f"Errors occurred: {e}")

    print(f"Processing complete. Total processed: {processed_count}, Success: {success_count}, Failure: {failure_count}")
# Out:
# 2025-01-07 07:37:48,319 - slines.utils.logging - INFO - 站点总数: 568
# 2025-01-07 07:37:56,653 - slines.utils.logging - INFO - 开始转换: 三亚市人民政府 (1/1) 数据量: 17614
# 2025-01-07 07:37:56,986 - slines.utils.logging - INFO - File exists: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚农业产业投资指南.docx
# 2025-01-07 07:37:57,210 - slines.utils.logging - INFO - Processing file: 三亚市人民政府\政策\政府信息公开专栏\政策文件\部门文件\三亚农业产业投资指南.docx
# 2025-01-07 07:37:57,212 - slines.utils.logging - INFO - Executing modified script fileId {'FileId': 105357478397830} -> 105357478397830
# 2025-01-07 07:37:57,214 - slines.utils.logging - INFO - Executing modified script filePath {'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\三亚农业产业投资指南.docx'} -> 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚农业产业投资指南.docx
# 2025-01-07 07:37:57,215 - slines.utils.logging - INFO - Executing modified script webSite 三亚市人民政府 -> 三亚市人民政府
# 2025-01-07 07:37:57,217 - slines.utils.logging - INFO - File already uploaded: 三亚市人民政府/be1b73de2e/105357478397830
# 2025-01-07 07:37:57,218 - slines.utils.logging - INFO - Executing modified script os_id {'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚农业产业投资指南.docx', 'webSite': '三亚市人民政府', 'fileId': 105357478397830, 'os_id': '三亚市人民政府/be1b73de2e/105357478397830'} -> 三亚市人民政府/be1b73de2e/105357478397830
# 2025-01-07 07:37:57,219 - slines.utils.logging - INFO - Executing modified script status {'GeneratedJson': None} -> 0
# 2025-01-07 07:37:57,219 - slines.utils.logging - INFO - Executing modified script isFormatted {'GeneratedJson': None} -> 0
# 2025-01-07 07:37:57,221 - slines.utils.logging - INFO - Executing modified script oldID 665057384726e81ab0707ab9 -> 665057384726e81ab0707ab9
# 2025-01-07 07:37:57,222 - slines.utils.logging - INFO - Executing modified script srcUrl http://ny.sanya.gov.cn/nyjsite/bmwjxx/202405/c6807a11a1f24dc6832406f74d8cbd74.shtml -> http://ny.sanya.gov.cn/nyjsite/bmwjxx/202405/c6807a11a1f24dc6832406f74d8cbd74.shtml
# 2025-01-07 07:37:57,223 - slines.utils.logging - INFO - Executing modified script categoryList ['政策', '政府信息公开专栏', '政策文件', '部门文件'] -> ['政策', '政府信息公开专栏', '政策文件', '部门文件']
# 2025-01-07 07:37:57,224 - slines.utils.logging - INFO - Executing modified script title 三亚农业产业投资指南 -> 三亚农业产业投资指南
# 2025-01-07 07:37:57,224 - slines.utils.logging - INFO - Executing modified script releaseDate {'date_str': '2024.05.23'} -> 1716422400000
# 2025-01-07 07:37:57,225 - slines.utils.logging - INFO - Executing modified script keywordList [] -> []
# 2025-01-07 07:37:57,225 - slines.utils.logging - INFO - Executing modified script issuer 三亚市农业农村局 -> 三亚市农业农村局
# 2025-01-07 07:37:57,226 - slines.utils.logging - INFO - Executing modified script issueNo  ->
# 2025-01-07 07:37:57,226 - slines.utils.logging - INFO - Executing modified script crawlTime {'date_str': '2024-05-24T17:00:33.343000'} -> 1716570033343
# 2025-01-07 07:37:57,227 - slines.utils.logging - INFO - Executing modified script repositoryList None -> None
# 2025-01-07 07:37:57,227 - slines.utils.logging - INFO - Executing modified script levelTypeList None -> None
# 2025-01-07 07:37:57,228 - slines.utils.logging - INFO - Executing modified script accessoryList {'Accessory': ['三亚农业产业投资指南（印刷版）.pdf'], 'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\三亚农业产业投资指南.docx'} -> ['三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚农业产业投资指南（印刷版）.pdf']
# 2025-01-07 07:37:57,229 - slines.utils.logging - INFO - Executing modified script attachmentList {'Attachment': None} -> []
# 2025-01-07 07:37:57,230 - slines.utils.logging - INFO - Executing remove script: FileId - FileId
# 2025-01-07 07:37:57,231 - slines.utils.logging - INFO - Executing remove script: SiteName - SiteName
# 2025-01-07 07:37:57,231 - slines.utils.logging - INFO - Executing remove script: Accessory - Accessory
# 2025-01-07 07:37:57,231 - slines.utils.logging - INFO - Executing remove script: FileDate - FileDate
# 2025-01-07 07:37:57,232 - slines.utils.logging - INFO - Executing remove script: CrawlTime - CrawlTime
# 2025-01-07 07:37:57,233 - slines.utils.logging - INFO - Executing remove script: Attachment - Attachment
# 2025-01-07 07:37:57,234 - slines.utils.logging - INFO - Executing remove script: Status - 删除旧的Status字段
# 2025-01-07 07:37:57,235 - slines.utils.logging - INFO - Executing remove script: GeneratedJson - 删除旧的GeneratedJson字段
# 2025-01-07 07:37:57,236 - slines.utils.logging - INFO - Executing remove script: FileName - FileName
# 2025-01-07 07:37:57,237 - slines.utils.logging - INFO - Executing remove script: verson - verson
# 2025-01-07 07:37:57,238 - slines.utils.logging - INFO - Executing remove script: Batch - Batch
# 2025-01-07 07:37:58,811 - slines.utils.logging - INFO - file_id: 105357478397830, file_path: 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚农业产业投资指南.docx
# 2025-01-07 07:38:02,635 - slines.utils.logging - INFO - File exists: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/关于邀请招标代理机构报价的公告.docx
# 2025-01-07 07:38:03,298 - slines.utils.logging - INFO - Processing file: 三亚市人民政府\政策\政府信息公开专栏\政策文件\部门文件\关于邀请招标代理机构报价的公告.docx
# 2025-01-07 07:38:03,299 - slines.utils.logging - INFO - Executing modified script fileId {'FileId': 105357484176070} -> 105357484176070
# 2025-01-07 07:38:03,300 - slines.utils.logging - INFO - Executing modified script filePath {'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\关于邀请招标代理机构报价的公告.docx'} -> 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/关于邀请招标代理机构报价的公告.docx
# 2025-01-07 07:38:03,301 - slines.utils.logging - INFO - Executing modified script webSite 三亚市人民政府 -> 三亚市人民政府
# 2025-01-07 07:38:03,301 - slines.utils.logging - INFO - File already uploaded: 三亚市人民政府/31b244429b/105357484176070
# 2025-01-07 07:38:03,302 - slines.utils.logging - INFO - Executing modified script os_id {'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/关于邀请招标代理机构报价的公告.docx', 'webSite': '三亚市人民政府', 'fileId': 105357484176070, 'os_id': '三亚市人民政府/31b244429b/105357484176070'} -> 三亚市人民政府/31b244429b/105357484176070
# 2025-01-07 07:38:03,302 - slines.utils.logging - INFO - Executing modified script status {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:03,303 - slines.utils.logging - INFO - Executing modified script isFormatted {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:03,303 - slines.utils.logging - INFO - Executing modified script oldID 6650573a4726e81ab0707aba -> 6650573a4726e81ab0707aba
# 2025-01-07 07:38:03,304 - slines.utils.logging - INFO - Executing modified script srcUrl http://www.sanya.gov.cn/fpbsite/bmwjxx/202405/3024b9bbea6d4b47ba1a5a9de3461347.shtml -> http://www.sanya.gov.cn/fpbsite/bmwjxx/202405/3024b9bbea6d4b47ba1a5a9de3461347.shtml
# 2025-01-07 07:38:03,304 - slines.utils.logging - INFO - Executing modified script categoryList ['政策', '政府信息公开专栏', '政策文件', '部门文件'] -> ['政策', '政府信息公开专栏', '政策文件', '部门文件']
# 2025-01-07 07:38:03,304 - slines.utils.logging - INFO - Executing modified script title 关于邀请招标代理机构报价的公告 -> 关于邀请招标代理机构报价的公告
# 2025-01-07 07:38:03,305 - slines.utils.logging - INFO - Executing modified script releaseDate {'date_str': '2024.05.23'} -> 1716422400000
# 2025-01-07 07:38:03,306 - slines.utils.logging - INFO - Executing modified script keywordList [] -> []
# 2025-01-07 07:38:03,306 - slines.utils.logging - INFO - Executing modified script issuer 三亚市乡村振兴局 -> 三亚市乡村振兴局
# 2025-01-07 07:38:03,306 - slines.utils.logging - INFO - Executing modified script issueNo  ->
# 2025-01-07 07:38:03,307 - slines.utils.logging - INFO - Executing modified script crawlTime {'date_str': '2024-05-24T17:00:42.005000'} -> 1716570042005
# 2025-01-07 07:38:03,307 - slines.utils.logging - INFO - Executing modified script repositoryList None -> None
# 2025-01-07 07:38:03,308 - slines.utils.logging - INFO - Executing modified script levelTypeList None -> None
# 2025-01-07 07:38:03,308 - slines.utils.logging - INFO - Executing modified script accessoryList {'Accessory': [], 'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\关于邀请招标代理机构报价的公告.docx'} -> []
# 2025-01-07 07:38:03,308 - slines.utils.logging - INFO - Executing modified script attachmentList {'Attachment': None} -> []
# 2025-01-07 07:38:03,309 - slines.utils.logging - INFO - Executing remove script: FileId - FileId
# 2025-01-07 07:38:03,310 - slines.utils.logging - INFO - Executing remove script: SiteName - SiteName
# 2025-01-07 07:38:03,310 - slines.utils.logging - INFO - Executing remove script: Accessory - Accessory
# 2025-01-07 07:38:03,310 - slines.utils.logging - INFO - Executing remove script: FileDate - FileDate
# 2025-01-07 07:38:03,313 - slines.utils.logging - INFO - Executing remove script: CrawlTime - CrawlTime
# 2025-01-07 07:38:03,314 - slines.utils.logging - INFO - Executing remove script: Attachment - Attachment
# 2025-01-07 07:38:03,314 - slines.utils.logging - INFO - Executing remove script: Status - 删除旧的Status字段
# 2025-01-07 07:38:03,315 - slines.utils.logging - INFO - Executing remove script: GeneratedJson - 删除旧的GeneratedJson字段
# 2025-01-07 07:38:03,315 - slines.utils.logging - INFO - Executing remove script: FileName - FileName
# 2025-01-07 07:38:03,316 - slines.utils.logging - INFO - Executing remove script: verson - verson
# 2025-01-07 07:38:03,316 - slines.utils.logging - INFO - Executing remove script: Batch - Batch
# 2025-01-07 07:38:03,510 - slines.utils.logging - INFO - file_id: 105357484176070, file_path: 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/关于邀请招标代理机构报价的公告.docx
# 2025-01-07 07:38:04,468 - slines.utils.logging - INFO - File exists: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市律师事务所2023年度检查考核结果公示.docx
# 2025-01-07 07:38:04,616 - slines.utils.logging - INFO - Processing file: 三亚市人民政府\政策\政府信息公开专栏\政策文件\部门文件\三亚市律师事务所2023年度检查考核结果公示.docx
# 2025-01-07 07:38:04,616 - slines.utils.logging - INFO - Executing modified script fileId {'FileId': 105357495346182} -> 105357495346182
# 2025-01-07 07:38:04,617 - slines.utils.logging - INFO - Executing modified script filePath {'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\三亚市律师事务所2023年度检查考核结果公示.docx'} -> 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市律师事务所2023年度检查考核结果公示.docx
# 2025-01-07 07:38:04,618 - slines.utils.logging - INFO - Executing modified script webSite 三亚市人民政府 -> 三亚市人民政府
# 2025-01-07 07:38:04,619 - slines.utils.logging - INFO - File already uploaded: 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:04,619 - slines.utils.logging - INFO - Executing modified script os_id {'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市律师事务所2023年度检查考核结果公示.docx', 'webSite': '三亚市人民政府', 'fileId': 105357495346182, 'os_id': '三亚市人民政府/ba18854d1c/105358426310214'} -> 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:04,620 - slines.utils.logging - INFO - Executing modified script status {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:04,620 - slines.utils.logging - INFO - Executing modified script isFormatted {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:04,621 - slines.utils.logging - INFO - Executing modified script oldID 6650573c4726e81ab0707abb -> 6650573c4726e81ab0707abb
# 2025-01-07 07:38:04,621 - slines.utils.logging - INFO - Executing modified script srcUrl http://www.sanya.gov.cn/sfjsite/bmwjxx/202405/a76216aae582422081cc4429dbb03367.shtml -> http://www.sanya.gov.cn/sfjsite/bmwjxx/202405/a76216aae582422081cc4429dbb03367.shtml
# 2025-01-07 07:38:04,622 - slines.utils.logging - INFO - Executing modified script categoryList ['政策', '政府信息公开专栏', '政策文件', '部门文件'] -> ['政策', '政府信息公开专栏', '政策文件', '部门文件']
# 2025-01-07 07:38:04,622 - slines.utils.logging - INFO - Executing modified script title 三亚市律师事务所2023年度检查考核结果公示 -> 三亚市律师事务所2023年度检查考核结果公示
# 2025-01-07 07:38:04,623 - slines.utils.logging - INFO - Executing modified script releaseDate {'date_str': '2024.05.22'} -> 1716336000000
# 2025-01-07 07:38:04,623 - slines.utils.logging - INFO - Executing modified script keywordList [] -> []
# 2025-01-07 07:38:04,623 - slines.utils.logging - INFO - Executing modified script issuer 三亚市司法局 -> 三亚市司法局
# 2025-01-07 07:38:04,624 - slines.utils.logging - INFO - Executing modified script issueNo  ->
# 2025-01-07 07:38:04,624 - slines.utils.logging - INFO - Executing modified script crawlTime {'date_str': '2024-05-24T17:00:42.795000'} -> 1716570042795
# 2025-01-07 07:38:04,625 - slines.utils.logging - INFO - Executing modified script repositoryList None -> None
# 2025-01-07 07:38:04,625 - slines.utils.logging - INFO - Executing modified script levelTypeList None -> None
# 2025-01-07 07:38:04,626 - slines.utils.logging - INFO - Executing modified script accessoryList {'Accessory': ['1.三亚市律师事务所2023年度检查考核结果公示.pdf', '2.三亚市2023年度律师事务所检查考核结果.xlsx'], 'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\三亚市律师事务所2023年度检查考核结果公示.docx'} -> ['三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/1.三亚市律师事务所2023年度检查考核结果公示.pdf', '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/2.三亚市2023年度律师事务所检查考核结果.xlsx']
# 2025-01-07 07:38:04,627 - slines.utils.logging - INFO - Executing modified script attachmentList {'Attachment': None} -> []
# 2025-01-07 07:38:04,627 - slines.utils.logging - INFO - Executing remove script: FileId - FileId
# 2025-01-07 07:38:04,628 - slines.utils.logging - INFO - Executing remove script: SiteName - SiteName
# 2025-01-07 07:38:04,630 - slines.utils.logging - INFO - Executing remove script: Accessory - Accessory
# 2025-01-07 07:38:04,631 - slines.utils.logging - INFO - Executing remove script: FileDate - FileDate
# 2025-01-07 07:38:04,632 - slines.utils.logging - INFO - Executing remove script: CrawlTime - CrawlTime
# 2025-01-07 07:38:04,632 - slines.utils.logging - INFO - Executing remove script: Attachment - Attachment
# 2025-01-07 07:38:04,632 - slines.utils.logging - INFO - Executing remove script: Status - 删除旧的Status字段
# 2025-01-07 07:38:04,633 - slines.utils.logging - INFO - Executing remove script: GeneratedJson - 删除旧的GeneratedJson字段
# 2025-01-07 07:38:04,633 - slines.utils.logging - INFO - Executing remove script: FileName - FileName
# 2025-01-07 07:38:04,634 - slines.utils.logging - INFO - Executing remove script: verson - verson
# 2025-01-07 07:38:04,634 - slines.utils.logging - INFO - Executing remove script: Batch - Batch
# 2025-01-07 07:38:04,824 - slines.utils.logging - INFO - file_id: 105357495346182, file_path: 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市律师事务所2023年度检查考核结果公示.docx
# 2025-01-07 07:38:05,312 - slines.utils.logging - INFO - File exists: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市热带作物技术推广服务中心关于有机肥、土壤改良剂、防治用药等询价公告.docx
# 2025-01-07 07:38:05,452 - slines.utils.logging - INFO - Processing file: 三亚市人民政府\政策\政府信息公开专栏\政策文件\部门文件\三亚市热带作物技术推广服务中心关于有机肥、土壤改良剂、防治用药等询价公告.docx
# 2025-01-07 07:38:05,453 - slines.utils.logging - INFO - Executing modified script fileId {'FileId': 105357505884550} -> 105357505884550
# 2025-01-07 07:38:05,453 - slines.utils.logging - INFO - Executing modified script filePath {'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\三亚市热带作物技术推广服务中心关于有机肥、土壤改良剂、防治用药等询价公告.docx'} -> 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市热带作物技术推广服务中心关于有机肥、土壤改良剂、防治用药等询价公告.docx
# 2025-01-07 07:38:05,454 - slines.utils.logging - INFO - Executing modified script webSite 三亚市人民政府 -> 三亚市人民政府
# 2025-01-07 07:38:05,454 - slines.utils.logging - INFO - File already uploaded: 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:05,455 - slines.utils.logging - INFO - Executing modified script os_id {'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市热带作物技术推广服务中心关于有机肥、土壤改良剂、防治用药等询价公告.docx', 'webSite': '三亚市人民政府', 'fileId': 105357505884550, 'os_id': '三亚市人民政府/ba18854d1c/105358426310214'} -> 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:05,455 - slines.utils.logging - INFO - Executing modified script status {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:05,455 - slines.utils.logging - INFO - Executing modified script isFormatted {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:05,456 - slines.utils.logging - INFO - Executing modified script oldID 6650573f4726e81ab0707abc -> 6650573f4726e81ab0707abc
# 2025-01-07 07:38:05,456 - slines.utils.logging - INFO - Executing modified script srcUrl http://ny.sanya.gov.cn/nyjsite/bmwjxx/202405/99ce41730e9940a2a8d25af95a724fbc.shtml -> http://ny.sanya.gov.cn/nyjsite/bmwjxx/202405/99ce41730e9940a2a8d25af95a724fbc.shtml
# 2025-01-07 07:38:05,456 - slines.utils.logging - INFO - Executing modified script categoryList ['政策', '政府信息公开专栏', '政策文件', '部门文件'] -> ['政策', '政府信息公开专栏', '政策文件', '部门文件']
# 2025-01-07 07:38:05,457 - slines.utils.logging - INFO - Executing modified script title 三亚市热带作物技术推广服务中心关于有机肥、土壤改良剂、防治用药等询价公告 -> 三亚市热带作物技术推广服务中心关于有机肥、土壤改良剂、防治用药等询价公告
# 2025-01-07 07:38:05,457 - slines.utils.logging - INFO - Executing modified script releaseDate {'date_str': '2024.05.20'} -> 1716163200000
# 2025-01-07 07:38:05,458 - slines.utils.logging - INFO - Executing modified script keywordList [] -> []
# 2025-01-07 07:38:05,458 - slines.utils.logging - INFO - Executing modified script issuer 三亚市农业农村局 -> 三亚市农业农村局
# 2025-01-07 07:38:05,458 - slines.utils.logging - INFO - Executing modified script issueNo  ->
# 2025-01-07 07:38:05,459 - slines.utils.logging - INFO - Executing modified script crawlTime {'date_str': '2024-05-24T17:00:47.299000'} -> 1716570047299
# 2025-01-07 07:38:05,459 - slines.utils.logging - INFO - Executing modified script repositoryList None -> None
# 2025-01-07 07:38:05,459 - slines.utils.logging - INFO - Executing modified script levelTypeList None -> None
# 2025-01-07 07:38:05,460 - slines.utils.logging - INFO - Executing modified script accessoryList {'Accessory': [], 'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\三亚市热带作物技术推广服务中心关于有机肥、土壤改良剂、防治用药等询价公告.docx'} -> []
# 2025-01-07 07:38:05,460 - slines.utils.logging - INFO - Executing modified script attachmentList {'Attachment': None} -> []
# 2025-01-07 07:38:05,461 - slines.utils.logging - INFO - Executing remove script: FileId - FileId
# 2025-01-07 07:38:05,461 - slines.utils.logging - INFO - Executing remove script: SiteName - SiteName
# 2025-01-07 07:38:05,461 - slines.utils.logging - INFO - Executing remove script: Accessory - Accessory
# 2025-01-07 07:38:05,462 - slines.utils.logging - INFO - Executing remove script: FileDate - FileDate
# 2025-01-07 07:38:05,462 - slines.utils.logging - INFO - Executing remove script: CrawlTime - CrawlTime
# 2025-01-07 07:38:05,464 - slines.utils.logging - INFO - Executing remove script: Attachment - Attachment
# 2025-01-07 07:38:05,464 - slines.utils.logging - INFO - Executing remove script: Status - 删除旧的Status字段
# 2025-01-07 07:38:05,465 - slines.utils.logging - INFO - Executing remove script: GeneratedJson - 删除旧的GeneratedJson字段
# 2025-01-07 07:38:05,466 - slines.utils.logging - INFO - Executing remove script: FileName - FileName
# 2025-01-07 07:38:05,467 - slines.utils.logging - INFO - Executing remove script: verson - verson
# 2025-01-07 07:38:05,467 - slines.utils.logging - INFO - Executing remove script: Batch - Batch
# 2025-01-07 07:38:05,690 - slines.utils.logging - INFO - file_id: 105357505884550, file_path: 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市热带作物技术推广服务中心关于有机肥、土壤改良剂、防治用药等询价公告.docx
# 2025-01-07 07:38:06,357 - slines.utils.logging - INFO - File exists: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚农业投资指南政策汇编（2024）.docx
# 2025-01-07 07:38:06,653 - slines.utils.logging - INFO - Processing file: 三亚市人民政府\政策\政府信息公开专栏\政策文件\部门文件\三亚农业投资指南政策汇编（2024）.docx
# 2025-01-07 07:38:06,654 - slines.utils.logging - INFO - Executing modified script fileId {'FileId': 105357600833862} -> 105357600833862
# 2025-01-07 07:38:06,655 - slines.utils.logging - INFO - Executing modified script filePath {'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\三亚农业投资指南政策汇编（2024）.docx'} -> 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚农业投资指南政策汇编（2024）.docx
# 2025-01-07 07:38:06,655 - slines.utils.logging - INFO - Executing modified script webSite 三亚市人民政府 -> 三亚市人民政府
# 2025-01-07 07:38:06,656 - slines.utils.logging - INFO - File already uploaded: 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:06,656 - slines.utils.logging - INFO - Executing modified script os_id {'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚农业投资指南政策汇编（2024）.docx', 'webSite': '三亚市人民政府', 'fileId': 105357600833862, 'os_id': '三亚市人民政府/ba18854d1c/105358426310214'} -> 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:06,657 - slines.utils.logging - INFO - Executing modified script status {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:06,657 - slines.utils.logging - INFO - Executing modified script isFormatted {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:06,658 - slines.utils.logging - INFO - Executing modified script oldID 665057564726e81ab0707abd -> 665057564726e81ab0707abd
# 2025-01-07 07:38:06,658 - slines.utils.logging - INFO - Executing modified script srcUrl http://ny.sanya.gov.cn/nyjsite/bmwjxx/202405/24815c43ce7d494d9a18cc66a600a778.shtml -> http://ny.sanya.gov.cn/nyjsite/bmwjxx/202405/24815c43ce7d494d9a18cc66a600a778.shtml
# 2025-01-07 07:38:06,659 - slines.utils.logging - INFO - Executing modified script categoryList ['政策', '政府信息公开专栏', '政策文件', '部门文件'] -> ['政策', '政府信息公开专栏', '政策文件', '部门文件']
# 2025-01-07 07:38:06,659 - slines.utils.logging - INFO - Executing modified script title 三亚农业投资指南政策汇编（2024） -> 三亚农业投资指南政策汇编（2024）
# 2025-01-07 07:38:06,660 - slines.utils.logging - INFO - Executing modified script releaseDate {'date_str': '2024.05.17'} -> 1715904000000
# 2025-01-07 07:38:06,661 - slines.utils.logging - INFO - Executing modified script keywordList [] -> []
# 2025-01-07 07:38:06,662 - slines.utils.logging - INFO - Executing modified script issuer 三亚市农业农村局 -> 三亚市农业农村局
# 2025-01-07 07:38:06,662 - slines.utils.logging - INFO - Executing modified script issueNo  ->
# 2025-01-07 07:38:06,663 - slines.utils.logging - INFO - Executing modified script crawlTime {'date_str': '2024-05-24T17:00:48.656000'} -> 1716570048656
# 2025-01-07 07:38:06,663 - slines.utils.logging - INFO - Executing modified script repositoryList None -> None
# 2025-01-07 07:38:06,663 - slines.utils.logging - INFO - Executing modified script levelTypeList None -> None
# 2025-01-07 07:38:06,664 - slines.utils.logging - INFO - Executing modified script accessoryList {'Accessory': ['附件：三亚农业产业投资指南政策汇编（2024）.pdf'], 'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\三亚农业投资指南政策汇编（2024）.docx'} -> ['三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/附件：三亚农业产业投资指南政策汇编（2024）.pdf']
# 2025-01-07 07:38:06,664 - slines.utils.logging - INFO - Executing modified script attachmentList {'Attachment': None} -> []
# 2025-01-07 07:38:06,664 - slines.utils.logging - INFO - Executing remove script: FileId - FileId
# 2025-01-07 07:38:06,665 - slines.utils.logging - INFO - Executing remove script: SiteName - SiteName
# 2025-01-07 07:38:06,665 - slines.utils.logging - INFO - Executing remove script: Accessory - Accessory
# 2025-01-07 07:38:06,666 - slines.utils.logging - INFO - Executing remove script: FileDate - FileDate
# 2025-01-07 07:38:06,666 - slines.utils.logging - INFO - Executing remove script: CrawlTime - CrawlTime
# 2025-01-07 07:38:06,667 - slines.utils.logging - INFO - Executing remove script: Attachment - Attachment
# 2025-01-07 07:38:06,667 - slines.utils.logging - INFO - Executing remove script: Status - 删除旧的Status字段
# 2025-01-07 07:38:06,668 - slines.utils.logging - INFO - Executing remove script: GeneratedJson - 删除旧的GeneratedJson字段
# 2025-01-07 07:38:06,668 - slines.utils.logging - INFO - Executing remove script: FileName - FileName
# 2025-01-07 07:38:06,668 - slines.utils.logging - INFO - Executing remove script: verson - verson
# 2025-01-07 07:38:06,669 - slines.utils.logging - INFO - Executing remove script: Batch - Batch
# 2025-01-07 07:38:06,827 - slines.utils.logging - INFO - file_id: 105357600833862, file_path: 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚农业投资指南政策汇编（2024）.docx
# 2025-01-07 07:38:07,333 - slines.utils.logging - INFO - File exists: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚农业产业招商项目简介汇编（2024）.docx
# 2025-01-07 07:38:07,745 - slines.utils.logging - INFO - Processing file: 三亚市人民政府\政策\政府信息公开专栏\政策文件\部门文件\三亚农业产业招商项目简介汇编（2024）.docx
# 2025-01-07 07:38:07,746 - slines.utils.logging - INFO - Executing modified script fileId {'FileId': 105357628245894} -> 105357628245894
# 2025-01-07 07:38:07,746 - slines.utils.logging - INFO - Executing modified script filePath {'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\三亚农业产业招商项目简介汇编（2024）.docx'} -> 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚农业产业招商项目简介汇编（2024）.docx
# 2025-01-07 07:38:07,747 - slines.utils.logging - INFO - Executing modified script webSite 三亚市人民政府 -> 三亚市人民政府
# 2025-01-07 07:38:07,747 - slines.utils.logging - INFO - File already uploaded: 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:07,748 - slines.utils.logging - INFO - Executing modified script os_id {'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚农业产业招商项目简介汇编（2024）.docx', 'webSite': '三亚市人民政府', 'fileId': 105357628245894, 'os_id': '三亚市人民政府/ba18854d1c/105358426310214'} -> 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:07,749 - slines.utils.logging - INFO - Executing modified script status {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:07,749 - slines.utils.logging - INFO - Executing modified script isFormatted {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:07,750 - slines.utils.logging - INFO - Executing modified script oldID 6650575d4726e81ab0707abe -> 6650575d4726e81ab0707abe
# 2025-01-07 07:38:07,750 - slines.utils.logging - INFO - Executing modified script srcUrl http://ny.sanya.gov.cn/nyjsite/bmwjxx/202405/037e41cf97444442a8d25ed23cdfdeb9.shtml -> http://ny.sanya.gov.cn/nyjsite/bmwjxx/202405/037e41cf97444442a8d25ed23cdfdeb9.shtml
# 2025-01-07 07:38:07,750 - slines.utils.logging - INFO - Executing modified script categoryList ['政策', '政府信息公开专栏', '政策文件', '部门文件'] -> ['政策', '政府信息公开专栏', '政策文件', '部门文件']
# 2025-01-07 07:38:07,751 - slines.utils.logging - INFO - Executing modified script title 三亚农业产业招商项目简介汇编（2024） -> 三亚农业产业招商项目简介汇编（2024）
# 2025-01-07 07:38:07,751 - slines.utils.logging - INFO - Executing modified script releaseDate {'date_str': '2024.05.17'} -> 1715904000000
# 2025-01-07 07:38:07,752 - slines.utils.logging - INFO - Executing modified script keywordList [] -> []
# 2025-01-07 07:38:07,752 - slines.utils.logging - INFO - Executing modified script issuer 三亚市农业农村局 -> 三亚市农业农村局
# 2025-01-07 07:38:07,752 - slines.utils.logging - INFO - Executing modified script issueNo  ->
# 2025-01-07 07:38:07,753 - slines.utils.logging - INFO - Executing modified script crawlTime {'date_str': '2024-05-24T17:01:11.087000'} -> 1716570071087
# 2025-01-07 07:38:07,753 - slines.utils.logging - INFO - Executing modified script repositoryList None -> None
# 2025-01-07 07:38:07,753 - slines.utils.logging - INFO - Executing modified script levelTypeList None -> None
# 2025-01-07 07:38:07,754 - slines.utils.logging - INFO - Executing modified script accessoryList {'Accessory': ['附件：三亚农业产业招商项目简介汇编（2024）.docx'], 'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\三亚农业产业招商项目简介汇编（2024）.docx'} -> ['三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/附件：三亚农业产业招商项目简介汇编（2024）.docx']
# 2025-01-07 07:38:07,754 - slines.utils.logging - INFO - Executing modified script attachmentList {'Attachment': [{'Name': '附件：三亚农业产业招商项目简介汇编（2024）.docx', 'Attachment_id': 244800357567429, 'Md5': '12a7741cc8d323aa345f705b117bd7f2', 'Size': 16929980}]} -> [{'Name': '附件：三亚农业产业招商项目简介汇编（2024）.docx', 'Attachment_id': 244800357567429, 'Md5': '12a7741cc8d323aa345f705b117bd7f2', 'Size': 16929980}]
# 2025-01-07 07:38:07,756 - slines.utils.logging - INFO - Executing remove script: FileId - FileId
# 2025-01-07 07:38:07,756 - slines.utils.logging - INFO - Executing remove script: SiteName - SiteName
# 2025-01-07 07:38:07,756 - slines.utils.logging - INFO - Executing remove script: Accessory - Accessory
# 2025-01-07 07:38:07,757 - slines.utils.logging - INFO - Executing remove script: FileDate - FileDate
# 2025-01-07 07:38:07,757 - slines.utils.logging - INFO - Executing remove script: CrawlTime - CrawlTime
# 2025-01-07 07:38:07,758 - slines.utils.logging - INFO - Executing remove script: Attachment - Attachment
# 2025-01-07 07:38:07,758 - slines.utils.logging - INFO - Executing remove script: Status - 删除旧的Status字段
# 2025-01-07 07:38:07,758 - slines.utils.logging - INFO - Executing remove script: GeneratedJson - 删除旧的GeneratedJson字段
# 2025-01-07 07:38:07,759 - slines.utils.logging - INFO - Executing remove script: FileName - FileName
# 2025-01-07 07:38:07,759 - slines.utils.logging - INFO - Executing remove script: verson - verson
# 2025-01-07 07:38:07,760 - slines.utils.logging - INFO - Executing remove script: Batch - Batch
# 2025-01-07 07:38:09,320 - slines.utils.logging - INFO - file_id: 105357628245894, file_path: 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚农业产业招商项目简介汇编（2024）.docx
# 2025-01-07 07:38:10,274 - slines.utils.logging - INFO - File exists: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市生态环境局关于发布2024年4月城镇内河（湖）水环境监测信息的公告.docx
# 2025-01-07 07:38:10,744 - slines.utils.logging - INFO - Processing file: 三亚市人民政府\政策\政府信息公开专栏\政策文件\部门文件\三亚市生态环境局关于发布2024年4月城镇内河（湖）水环境监测信息的公告.docx
# 2025-01-07 07:38:10,745 - slines.utils.logging - INFO - Executing modified script fileId {'FileId': 105357633900806} -> 105357633900806
# 2025-01-07 07:38:10,745 - slines.utils.logging - INFO - Executing modified script filePath {'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\三亚市生态环境局关于发布2024年4月城镇内河（湖）水环境监测信息的公告.docx'} -> 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市生态环境局关于发布2024年4月城镇内河（湖）水环境监测信息的公告.docx
# 2025-01-07 07:38:10,746 - slines.utils.logging - INFO - Executing modified script webSite 三亚市人民政府 -> 三亚市人民政府
# 2025-01-07 07:38:10,746 - slines.utils.logging - INFO - File already uploaded: 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:10,747 - slines.utils.logging - INFO - Executing modified script os_id {'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市生态环境局关于发布2024年4月城镇内河（湖）水环境监测信息的公告.docx', 'webSite': '三亚市人民政府', 'fileId': 105357633900806, 'os_id': '三亚市人民政府/ba18854d1c/105358426310214'} -> 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:10,747 - slines.utils.logging - INFO - Executing modified script status {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:10,748 - slines.utils.logging - INFO - Executing modified script isFormatted {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:10,748 - slines.utils.logging - INFO - Executing modified script oldID 6650575e4726e81ab0707abf -> 6650575e4726e81ab0707abf
# 2025-01-07 07:38:10,749 - slines.utils.logging - INFO - Executing modified script srcUrl http://hbj.sanya.gov.cn/sthjsite/bmwjxx/202405/e8e236fb60384209b281519477f69023.shtml -> http://hbj.sanya.gov.cn/sthjsite/bmwjxx/202405/e8e236fb60384209b281519477f69023.shtml
# 2025-01-07 07:38:10,749 - slines.utils.logging - INFO - Executing modified script categoryList ['政策', '政府信息公开专栏', '政策文件', '部门文件'] -> ['政策', '政府信息公开专栏', '政策文件', '部门文件']
# 2025-01-07 07:38:10,750 - slines.utils.logging - INFO - Executing modified script title 三亚市生态环境局关于发布2024年4月城镇内河（湖）水环境监测信息的公告 -> 三亚市生态环境局关于发布2024年4月城镇内河（湖）水环境监测信息的公告
# 2025-01-07 07:38:10,750 - slines.utils.logging - INFO - Executing modified script releaseDate {'date_str': '2024.05.17'} -> 1715904000000
# 2025-01-07 07:38:10,751 - slines.utils.logging - INFO - Executing modified script keywordList [] -> []
# 2025-01-07 07:38:10,751 - slines.utils.logging - INFO - Executing modified script issuer 三亚市生态环境局 -> 三亚市生态环境局
# 2025-01-07 07:38:10,752 - slines.utils.logging - INFO - Executing modified script issueNo  ->
# 2025-01-07 07:38:10,752 - slines.utils.logging - INFO - Executing modified script crawlTime {'date_str': '2024-05-24T17:01:17.691000'} -> 1716570077691
# 2025-01-07 07:38:10,753 - slines.utils.logging - INFO - Executing modified script repositoryList None -> None
# 2025-01-07 07:38:10,753 - slines.utils.logging - INFO - Executing modified script levelTypeList None -> None
# 2025-01-07 07:38:10,753 - slines.utils.logging - INFO - Executing modified script accessoryList {'Accessory': ['附件：三亚市城镇内河（湖）水环境月报（2024年第4期）.pdf'], 'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\三亚市生态环境局关于发布2024年4月城镇内河（湖）水环境监测信息的公告.docx'} -> ['三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/附件：三亚市城镇内河（湖）水环境月报（2024年第4期）.pdf']
# 2025-01-07 07:38:10,754 - slines.utils.logging - INFO - Executing modified script attachmentList {'Attachment': [{'Name': '附件：三亚市城镇内河（湖）水环境月报（2024年第4期）.pdf', 'Attachment_id': 244800228576197, 'Md5': 'c7edcf9e2e85a206cf8d4c1105705d4a', 'Size': 821276}]} -> [{'Name': '附件：三亚市城镇内河（湖）水环境月报（2024年第4期）.pdf', 'Attachment_id': 244800228576197, 'Md5': 'c7edcf9e2e85a206cf8d4c1105705d4a', 'Size': 821276}]
# 2025-01-07 07:38:10,754 - slines.utils.logging - INFO - Executing remove script: FileId - FileId
# 2025-01-07 07:38:10,755 - slines.utils.logging - INFO - Executing remove script: SiteName - SiteName
# 2025-01-07 07:38:10,755 - slines.utils.logging - INFO - Executing remove script: Accessory - Accessory
# 2025-01-07 07:38:10,756 - slines.utils.logging - INFO - Executing remove script: FileDate - FileDate
# 2025-01-07 07:38:10,757 - slines.utils.logging - INFO - Executing remove script: CrawlTime - CrawlTime
# 2025-01-07 07:38:10,757 - slines.utils.logging - INFO - Executing remove script: Attachment - Attachment
# 2025-01-07 07:38:10,758 - slines.utils.logging - INFO - Executing remove script: Status - 删除旧的Status字段
# 2025-01-07 07:38:10,758 - slines.utils.logging - INFO - Executing remove script: GeneratedJson - 删除旧的GeneratedJson字段
# 2025-01-07 07:38:10,759 - slines.utils.logging - INFO - Executing remove script: FileName - FileName
# 2025-01-07 07:38:10,759 - slines.utils.logging - INFO - Executing remove script: verson - verson
# 2025-01-07 07:38:10,760 - slines.utils.logging - INFO - Executing remove script: Batch - Batch
# 2025-01-07 07:38:11,053 - slines.utils.logging - INFO - file_id: 105357633900806, file_path: 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市生态环境局关于发布2024年4月城镇内河（湖）水环境监测信息的公告.docx
# 2025-01-07 07:38:12,169 - slines.utils.logging - INFO - File exists: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/海南省商务厅关于印发《海南省推动消费品以旧换新行动实施方案》的通知.docx
# 2025-01-07 07:38:12,431 - slines.utils.logging - INFO - Processing file: 三亚市人民政府\政策\政府信息公开专栏\政策文件\部门文件\海南省商务厅关于印发《海南省推动消费品以旧换新行动实施方案》的通知.docx
# 2025-01-07 07:38:12,431 - slines.utils.logging - INFO - Executing modified script fileId {'FileId': 105357637092678} -> 105357637092678
# 2025-01-07 07:38:12,432 - slines.utils.logging - INFO - Executing modified script filePath {'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\海南省商务厅关于印发《海南省推动消费品以旧换新行动实施方案》的通知.docx'} -> 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/海南省商务厅关于印发《海南省推动消费品以旧换新行动实施方案》的通知.docx
# 2025-01-07 07:38:12,433 - slines.utils.logging - INFO - Executing modified script webSite 三亚市人民政府 -> 三亚市人民政府
# 2025-01-07 07:38:12,433 - slines.utils.logging - INFO - File already uploaded: 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:12,434 - slines.utils.logging - INFO - Executing modified script os_id {'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/海南省商务厅关于印发《海南省推动消费品以旧换新行动实施方案》的通知.docx', 'webSite': '三亚市人民政府', 'fileId': 105357637092678, 'os_id': '三亚市人民政府/ba18854d1c/105358426310214'} -> 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:12,434 - slines.utils.logging - INFO - Executing modified script status {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:12,434 - slines.utils.logging - INFO - Executing modified script isFormatted {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:12,435 - slines.utils.logging - INFO - Executing modified script oldID 6650575f4726e81ab0707ac0 -> 6650575f4726e81ab0707ac0
# 2025-01-07 07:38:12,435 - slines.utils.logging - INFO - Executing modified script srcUrl http://swj.sanya.gov.cn/swjsite/bmwjxx/202405/ddc18d10820c45b382c4a4487c25c51f.shtml -> http://swj.sanya.gov.cn/swjsite/bmwjxx/202405/ddc18d10820c45b382c4a4487c25c51f.shtml
# 2025-01-07 07:38:12,436 - slines.utils.logging - INFO - Executing modified script categoryList ['政策', '政府信息公开专栏', '政策文件', '部门文件'] -> ['政策', '政府信息公开专栏', '政策文件', '部门文件']
# 2025-01-07 07:38:12,436 - slines.utils.logging - INFO - Executing modified script title 海南省商务厅关于印发《海南省推动消费品以旧换新行动实施方案》的通知 -> 海南省商务厅关于印发《海南省推动消费品以旧换新行动实施方案》的通知
# 2025-01-07 07:38:12,437 - slines.utils.logging - INFO - Executing modified script releaseDate {'date_str': '2024.05.15'} -> 1715731200000
# 2025-01-07 07:38:12,437 - slines.utils.logging - INFO - Executing modified script keywordList [] -> []
# 2025-01-07 07:38:12,437 - slines.utils.logging - INFO - Executing modified script issuer 三亚市商务局 -> 三亚市商务局
# 2025-01-07 07:38:12,438 - slines.utils.logging - INFO - Executing modified script issueNo  ->
# 2025-01-07 07:38:12,438 - slines.utils.logging - INFO - Executing modified script crawlTime {'date_str': '2024-05-24T17:01:19.325000'} -> 1716570079325
# 2025-01-07 07:38:12,438 - slines.utils.logging - INFO - Executing modified script repositoryList None -> None
# 2025-01-07 07:38:12,439 - slines.utils.logging - INFO - Executing modified script levelTypeList None -> None
# 2025-01-07 07:38:12,439 - slines.utils.logging - INFO - Executing modified script accessoryList {'Accessory': [], 'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\海南省商务厅关于印发《海南省推动消费品以旧换新行动实施方案》的通知.docx'} -> []
# 2025-01-07 07:38:12,439 - slines.utils.logging - INFO - Executing modified script attachmentList {'Attachment': None} -> []
# 2025-01-07 07:38:12,440 - slines.utils.logging - INFO - Executing remove script: FileId - FileId
# 2025-01-07 07:38:12,440 - slines.utils.logging - INFO - Executing remove script: SiteName - SiteName
# 2025-01-07 07:38:12,440 - slines.utils.logging - INFO - Executing remove script: Accessory - Accessory
# 2025-01-07 07:38:12,440 - slines.utils.logging - INFO - Executing remove script: FileDate - FileDate
# 2025-01-07 07:38:12,441 - slines.utils.logging - INFO - Executing remove script: CrawlTime - CrawlTime
# 2025-01-07 07:38:12,441 - slines.utils.logging - INFO - Executing remove script: Attachment - Attachment
# 2025-01-07 07:38:12,441 - slines.utils.logging - INFO - Executing remove script: Status - 删除旧的Status字段
# 2025-01-07 07:38:12,441 - slines.utils.logging - INFO - Executing remove script: GeneratedJson - 删除旧的GeneratedJson字段
# 2025-01-07 07:38:12,442 - slines.utils.logging - INFO - Executing remove script: FileName - FileName
# 2025-01-07 07:38:12,442 - slines.utils.logging - INFO - Executing remove script: verson - verson
# 2025-01-07 07:38:12,442 - slines.utils.logging - INFO - Executing remove script: Batch - Batch
# 2025-01-07 07:38:12,640 - slines.utils.logging - INFO - file_id: 105357637092678, file_path: 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/海南省商务厅关于印发《海南省推动消费品以旧换新行动实施方案》的通知.docx
# 2025-01-07 07:38:13,041 - slines.utils.logging - INFO - File exists: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/三亚市教育局 三亚市语言文字工作委员会办公室关于组织开展2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛（三亚赛区）系列活动的通知.docx
# 2025-01-07 07:38:13,341 - slines.utils.logging - INFO - Processing file: 三亚市人民政府\政策\政府信息公开专栏\政策文件\部门文件\科技、教育;\三亚市教育局 三亚市语言文字工作委员会办公室关于组织开展2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛（三亚赛区）系列活动的通知.docx
# 2025-01-07 07:38:13,343 - slines.utils.logging - INFO - Executing modified script fileId {'FileId': 105357667072774} -> 105357667072774
# 2025-01-07 07:38:13,343 - slines.utils.logging - INFO - Executing modified script filePath {'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\科技、教育;\\三亚市教育局 三亚市语言文字工作委员会办公室关于组织开展2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛（三亚赛区）系列活动的通知.docx'} -> 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/三亚市教育局 三亚市语言文字工作委员会办公室关于组织开展2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛（三亚赛区）系列活动的通知.docx
# 2025-01-07 07:38:13,344 - slines.utils.logging - INFO - Executing modified script webSite 三亚市人民政府 -> 三亚市人民政府
# 2025-01-07 07:38:13,344 - slines.utils.logging - INFO - File already uploaded: 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:13,345 - slines.utils.logging - INFO - Executing modified script os_id {'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/三亚市教育局 三亚市语言文字工作委员会办公室关于组织开展2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛（三亚赛区）系列活动的通知.docx', 'webSite': '三亚市人民政府', 'fileId': 105357667072774, 'os_id': '三亚市人民政府/ba18854d1c/105358426310214'} -> 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:13,345 - slines.utils.logging - INFO - Executing modified script status {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:13,347 - slines.utils.logging - INFO - Executing modified script isFormatted {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:13,347 - slines.utils.logging - INFO - Executing modified script oldID 665057664726e81ab0707ac1 -> 665057664726e81ab0707ac1
# 2025-01-07 07:38:13,348 - slines.utils.logging - INFO - Executing modified script srcUrl http://edu.sanya.gov.cn/jyjsite/bmwjxx/202405/df5184d6db914d44a57186068da3d4c6.shtml -> http://edu.sanya.gov.cn/jyjsite/bmwjxx/202405/df5184d6db914d44a57186068da3d4c6.shtml
# 2025-01-07 07:38:13,348 - slines.utils.logging - INFO - Executing modified script categoryList ['政策', '政府信息公开专栏', '政策文件', '部门文件', '科技、教育;'] -> ['政策', '政府信息公开专栏', '政策文件', '部门文件', '科技、教育;']
# 2025-01-07 07:38:13,349 - slines.utils.logging - INFO - Executing modified script title 三亚市教育局 三亚市语言文字工作委员会办公室关于组织开展2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛（三亚赛区）系列活动的通知 -> 三亚市教育局 三亚市语言文字工作委员会办公室关于组织开展2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛（三亚赛区）系列活动的通知
# 2025-01-07 07:38:13,350 - slines.utils.logging - INFO - Executing modified script releaseDate {'date_str': '2024.05.14'} -> 1715644800000
# 2025-01-07 07:38:13,351 - slines.utils.logging - INFO - Executing modified script keywordList [] -> []
# 2025-01-07 07:38:13,351 - slines.utils.logging - INFO - Executing modified script issuer 三亚市教育局 -> 三亚市教育局
# 2025-01-07 07:38:13,352 - slines.utils.logging - INFO - Executing modified script issueNo 三教语〔2024〕8号 -> 三教语〔2024〕8号
# 2025-01-07 07:38:13,352 - slines.utils.logging - INFO - Executing modified script crawlTime {'date_str': '2024-05-24T17:01:20.043000'} -> 1716570080043
# 2025-01-07 07:38:13,353 - slines.utils.logging - INFO - Executing modified script repositoryList None -> None
# 2025-01-07 07:38:13,354 - slines.utils.logging - INFO - Executing modified script levelTypeList None -> None
# 2025-01-07 07:38:13,354 - slines.utils.logging - INFO - Executing modified script accessoryList {'Accessory': ['附件1：海南省教育厅海南省语言文字工作委员会关于组织开展2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛系列活动的通知.pdf', '附件2：2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛“诵读中国”经典诵读大赛（三亚赛区）方案.doc', '附件3：2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛“诵读中国”经典诵读大赛（三亚赛区）名额分配表.docx', '附件4：2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛“诵读中国”经典诵读大赛（三亚赛区）活动作品汇总表.xls', '附件5：中华经典诵写讲大赛（”诗教中国“诗词讲解大赛、“笔墨中国”汉字书写大赛、“印记中国”师生篆刻大赛）作品汇总表.xls'], 'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\科技、教育;\\三亚市教育局 三亚市语言文字工作委员会办公室关于组织开展2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛（三亚赛区）系列活动的通知.docx'} -> ['三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/附件1：海南省教育厅海南省语言文字工作委员会关于组织开展2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛系列活动的通知.pdf', '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/附件2：2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛“诵读中国”经典诵读大赛（三亚赛区）方案.doc', '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/附件3：2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛“诵读中国”经典诵读大赛（三亚赛区）名额分配表.docx', '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/附件4：2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛“诵读中国”经典诵读大赛（三亚赛区）活动作品汇总表.xls', '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/附件5：中华经典诵写讲大赛（”诗教中国“诗词讲解大赛、“笔墨中国”汉字书写大赛、“印记中国”师生篆刻大赛）作品汇总表.xls']
# 2025-01-07 07:38:13,355 - slines.utils.logging - INFO - Executing modified script attachmentList {'Attachment': [{'Name': '附件1：海南省教育厅海南省语言文字工作委员会关于组织开展2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛系列活动的通知.pdf', 'Attachment_id': 244800210127813, 'Md5': '284841645797da5bf20f3c55b93c2c03', 'Size': 20212268}, {'Name': '附件2：2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛“诵读中国”经典诵读大赛（三亚赛区）方案.doc', 'Attachment_id': 244800213289925, 'Md5': '8ee07f6c20c6a48355a68b0701201642', 'Size': 27212}, {'Name': '附件3：2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛“诵读中国”经典诵读大赛（三亚赛区）名额分配表.docx', 'Attachment_id': 244800216468421, 'Md5': '859e37d9529a0d199f2d7bdcc37273b4', 'Size': 16956}, {'Name': '附件4：2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛“诵读中国”经典诵读大赛（三亚赛区）活动作品汇总表.xls', 'Attachment_id': 244800219360197, 'Md5': '87a3637df2da95a47044b01e0b57750c', 'Size': 16460}, {'Name': '附件5：中华经典诵写讲大赛（”诗教中国“诗词讲解大赛、“笔墨中国”汉字书写大赛、“印记中国”师生篆刻大赛）作品汇总表.xls', 'Attachment_id': 244800222251973, 'Md5': 'f39409fa58a6b8a15a297c8b7c8af826', 'Size': 16972}]} -> [{'Name': '附件1：海南省教育厅海南省语言文字工作委员会关于组织开展2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛系列活动的通知.pdf', 'Attachment_id': 244800210127813, 'Md5': '284841645797da5bf20f3c55b93c2c03', 'Size': 20212268}, {'Name': '附件2：2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛“诵读中国”经典诵读大赛（三亚赛区）方案.doc', 'Attachment_id': 244800213289925, 'Md5': '8ee07f6c20c6a48355a68b0701201642', 'Size': 27212}, {'Name': '附件3：2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛“诵读中国”经典诵读大赛（三亚赛区）名额分配表.docx', 'Attachment_id': 244800216468421, 'Md5': '859e37d9529a0d199f2d7bdcc37273b4', 'Size': 16956}, {'Name': '附件4：2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛“诵读中国”经典诵读大赛（三亚赛区）活动作品汇总表.xls', 'Attachment_id': 244800219360197, 'Md5': '87a3637df2da95a47044b01e0b57750c', 'Size': 16460}, {'Name': '附件5：中华经典诵写讲大赛（”诗教中国“诗词讲解大赛、“笔墨中国”汉字书写大赛、“印记中国”师生篆刻大赛）作品汇总表.xls', 'Attachment_id': 244800222251973, 'Md5': 'f39409fa58a6b8a15a297c8b7c8af826', 'Size': 16972}]
# 2025-01-07 07:38:13,356 - slines.utils.logging - INFO - Executing remove script: FileId - FileId
# 2025-01-07 07:38:13,356 - slines.utils.logging - INFO - Executing remove script: SiteName - SiteName
# 2025-01-07 07:38:13,357 - slines.utils.logging - INFO - Executing remove script: Accessory - Accessory
# 2025-01-07 07:38:13,357 - slines.utils.logging - INFO - Executing remove script: FileDate - FileDate
# 2025-01-07 07:38:13,358 - slines.utils.logging - INFO - Executing remove script: CrawlTime - CrawlTime
# 2025-01-07 07:38:13,358 - slines.utils.logging - INFO - Executing remove script: Attachment - Attachment
# 2025-01-07 07:38:13,358 - slines.utils.logging - INFO - Executing remove script: Status - 删除旧的Status字段
# 2025-01-07 07:38:13,359 - slines.utils.logging - INFO - Executing remove script: GeneratedJson - 删除旧的GeneratedJson字段
# 2025-01-07 07:38:13,359 - slines.utils.logging - INFO - Executing remove script: FileName - FileName
# 2025-01-07 07:38:13,360 - slines.utils.logging - INFO - Executing remove script: verson - verson
# 2025-01-07 07:38:13,361 - slines.utils.logging - INFO - Executing remove script: Batch - Batch
# 2025-01-07 07:38:13,602 - slines.utils.logging - INFO - file_id: 105357667072774, file_path: 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/三亚市教育局 三亚市语言文字工作委员会办公室关于组织开展2024年“典耀中华”主题读书行动暨第六届中华经典诵写讲大赛（三亚赛区）系列活动的通知.docx
# 2025-01-07 07:38:14,031 - slines.utils.logging - INFO - File exists: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市林业局关于《三亚市临春岭省级森林公园总体规划（2024-2035年）》（征求意见稿）公开征求意见的公告.docx
# 2025-01-07 07:38:14,442 - slines.utils.logging - INFO - Processing file: 三亚市人民政府\政策\政府信息公开专栏\政策文件\部门文件\三亚市林业局关于《三亚市临春岭省级森林公园总体规划（2024-2035年）》（征求意见稿）公开征求意见的公告.docx
# 2025-01-07 07:38:14,443 - slines.utils.logging - INFO - Executing modified script fileId {'FileId': 105357691435974} -> 105357691435974
# 2025-01-07 07:38:14,443 - slines.utils.logging - INFO - Executing modified script filePath {'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\三亚市林业局关于《三亚市临春岭省级森林公园总体规划（2024-2035年）》（征求意见稿）公开征求意见的公告.docx'} -> 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市林业局关于《三亚市临春岭省级森林公园总体规划（2024-2035年）》（征求意见稿）公开征求意见的公告.docx
# 2025-01-07 07:38:14,444 - slines.utils.logging - INFO - Executing modified script webSite 三亚市人民政府 -> 三亚市人民政府
# 2025-01-07 07:38:14,444 - slines.utils.logging - INFO - File already uploaded: 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:14,445 - slines.utils.logging - INFO - Executing modified script os_id {'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市林业局关于《三亚市临春岭省级森林公园总体规划（2024-2035年）》（征求意见稿）公开征求意见的公告.docx', 'webSite': '三亚市人民政府', 'fileId': 105357691435974, 'os_id': '三亚市人民政府/ba18854d1c/105358426310214'} -> 三亚市人民政府/ba18854d1c/105358426310214
# 2025-01-07 07:38:14,445 - slines.utils.logging - INFO - Executing modified script status {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:14,446 - slines.utils.logging - INFO - Executing modified script isFormatted {'GeneratedJson': None} -> 0
# 2025-01-07 07:38:14,447 - slines.utils.logging - INFO - Executing modified script oldID 6650576c4726e81ab0707ac2 -> 6650576c4726e81ab0707ac2
# 2025-01-07 07:38:14,448 - slines.utils.logging - INFO - Executing modified script srcUrl http://lyj.sanya.gov.cn/lyjsite/bmwjxx/202405/9d2a61b57c4a4aa38534954cde978459.shtml -> http://lyj.sanya.gov.cn/lyjsite/bmwjxx/202405/9d2a61b57c4a4aa38534954cde978459.shtml
# 2025-01-07 07:38:14,448 - slines.utils.logging - INFO - Executing modified script categoryList ['政策', '政府信息公开专栏', '政策文件', '部门文件'] -> ['政策', '政府信息公开专栏', '政策文件', '部门文件']
# 2025-01-07 07:38:14,449 - slines.utils.logging - INFO - Executing modified script title 三亚市林业局关于《三亚市临春岭省级森林公园总体规划（2024-2035年）》（征求意见稿）公开征求意见的公告 -> 三亚市林业局关于《三亚市临春岭省级森林公园总体规划（2024-2035年）》（征求意见稿）公开征求意见的公告
# 2025-01-07 07:38:14,449 - slines.utils.logging - INFO - Executing modified script releaseDate {'date_str': '2024.05.14'} -> 1715644800000
# 2025-01-07 07:38:14,449 - slines.utils.logging - INFO - Executing modified script keywordList [] -> []
# ...
# 2025-01-07 07:40:42,356 - slines.utils.logging - INFO - Executing modified script attachmentList {'Attachment': None} -> []
# 2025-01-07 07:40:42,356 - slines.utils.logging - INFO - Executing remove script: FileId - FileId
# 2025-01-07 07:40:42,357 - slines.utils.logging - INFO - Executing remove script: SiteName - SiteName
# 2025-01-07 07:40:42,357 - slines.utils.logging - INFO - Executing remove script: Accessory - Accessory
# 2025-01-07 07:40:42,357 - slines.utils.logging - INFO - Executing remove script: FileDate - FileDate
# 2025-01-07 07:40:42,358 - slines.utils.logging - INFO - Executing remove script: CrawlTime - CrawlTime
# 2025-01-07 07:40:42,358 - slines.utils.logging - INFO - Executing remove script: Attachment - Attachment
# 2025-01-07 07:40:42,359 - slines.utils.logging - INFO - Executing remove script: Status - 删除旧的Status字段
# 2025-01-07 07:40:42,359 - slines.utils.logging - INFO - Executing remove script: GeneratedJson - 删除旧的GeneratedJson字段
# 2025-01-07 07:40:42,359 - slines.utils.logging - INFO - Executing remove script: FileName - FileName
# 2025-01-07 07:40:42,360 - slines.utils.logging - INFO - Executing remove script: verson - verson
# 2025-01-07 07:40:42,361 - slines.utils.logging - INFO - Executing remove script: Batch - Batch
# 2025-01-07 07:40:42,546 - slines.utils.logging - INFO - file_id: 105358471198726, file_path: 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/三亚市商品房预售变更公告_1716541482985.docx
# 2025-01-07 07:40:44,016 - slines.utils.logging - INFO - File exists: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/关于对全国和全省“八五”普法中期通报表扬单位和个人的公示.docx
# 2025-01-07 07:40:44,168 - slines.utils.logging - INFO - Processing file: 三亚市人民政府\政策\政府信息公开专栏\政策文件\部门文件\关于对全国和全省“八五”普法中期通报表扬单位和个人的公示.docx
# 2025-01-07 07:40:44,169 - slines.utils.logging - INFO - Executing modified script fileId {'FileId': 105358473980294} -> 105358473980294
# 2025-01-07 07:40:44,169 - slines.utils.logging - INFO - Executing modified script filePath {'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\关于对全国和全省“八五”普法中期通报表扬单位和个人的公示.docx'} -> 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/关于对全国和全省“八五”普法中期通报表扬单位和个人的公示.docx
# 2025-01-07 07:40:44,170 - slines.utils.logging - INFO - Executing modified script webSite 三亚市人民政府 -> 三亚市人民政府
# 2025-01-07 07:40:44,171 - slines.utils.logging - INFO - File already uploaded: 三亚市人民政府/e4dcac2aee/105358473980294
# 2025-01-07 07:40:44,172 - slines.utils.logging - INFO - Executing modified script os_id {'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/关于对全国和全省“八五”普法中期通报表扬单位和个人的公示.docx', 'webSite': '三亚市人民政府', 'fileId': 105358473980294, 'os_id': '三亚市人民政府/e4dcac2aee/105358473980294'} -> 三亚市人民政府/e4dcac2aee/105358473980294
# 2025-01-07 07:40:44,173 - slines.utils.logging - INFO - Executing modified script status {'GeneratedJson': None} -> 0
# 2025-01-07 07:40:44,174 - slines.utils.logging - INFO - Executing modified script isFormatted {'GeneratedJson': None} -> 0
# 2025-01-07 07:40:44,175 - slines.utils.logging - INFO - Executing modified script oldID 6650582b4726e81ab0707b1b -> 6650582b4726e81ab0707b1b
# 2025-01-07 07:40:44,176 - slines.utils.logging - INFO - Executing modified script srcUrl http://www.sanya.gov.cn/sfjsite/bmwjxx/202404/9b6a442e7b0c48b59849a61c4e07558e.shtml -> http://www.sanya.gov.cn/sfjsite/bmwjxx/202404/9b6a442e7b0c48b59849a61c4e07558e.shtml
# 2025-01-07 07:40:44,178 - slines.utils.logging - INFO - Executing modified script categoryList ['政策', '政府信息公开专栏', '政策文件', '部门文件'] -> ['政策', '政府信息公开专栏', '政策文件', '部门文件']
# 2025-01-07 07:40:44,179 - slines.utils.logging - INFO - Executing modified script title 关于对全国和全省“八五”普法中期通报表扬单位和个人的公示 -> 关于对全国和全省“八五”普法中期通报表扬单位和个人的公示
# 2025-01-07 07:40:44,180 - slines.utils.logging - INFO - Executing modified script releaseDate {'date_str': '2024.04.03'} -> 1712102400000
# 2025-01-07 07:40:44,182 - slines.utils.logging - INFO - Executing modified script keywordList [] -> []
# 2025-01-07 07:40:44,183 - slines.utils.logging - INFO - Executing modified script issuer 三亚市司法局 -> 三亚市司法局
# 2025-01-07 07:40:44,185 - slines.utils.logging - INFO - Executing modified script issueNo  ->
# 2025-01-07 07:40:44,185 - slines.utils.logging - INFO - Executing modified script crawlTime {'date_str': '2024-05-24T17:04:43.654000'} -> 1716570283654
# 2025-01-07 07:40:44,186 - slines.utils.logging - INFO - Executing modified script repositoryList None -> None
# 2025-01-07 07:40:44,187 - slines.utils.logging - INFO - Executing modified script levelTypeList None -> None
# 2025-01-07 07:40:44,187 - slines.utils.logging - INFO - Executing modified script accessoryList {'Accessory': [], 'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\关于对全国和全省“八五”普法中期通报表扬单位和个人的公示.docx'} -> []
# 2025-01-07 07:40:44,188 - slines.utils.logging - INFO - Executing modified script attachmentList {'Attachment': None} -> []
# 2025-01-07 07:40:44,188 - slines.utils.logging - INFO - Executing remove script: FileId - FileId
# 2025-01-07 07:40:44,188 - slines.utils.logging - INFO - Executing remove script: SiteName - SiteName
# 2025-01-07 07:40:44,189 - slines.utils.logging - INFO - Executing remove script: Accessory - Accessory
# 2025-01-07 07:40:44,189 - slines.utils.logging - INFO - Executing remove script: FileDate - FileDate
# 2025-01-07 07:40:44,189 - slines.utils.logging - INFO - Executing remove script: CrawlTime - CrawlTime
# 2025-01-07 07:40:44,190 - slines.utils.logging - INFO - Executing remove script: Attachment - Attachment
# 2025-01-07 07:40:44,190 - slines.utils.logging - INFO - Executing remove script: Status - 删除旧的Status字段
# 2025-01-07 07:40:44,190 - slines.utils.logging - INFO - Executing remove script: GeneratedJson - 删除旧的GeneratedJson字段
# 2025-01-07 07:40:44,191 - slines.utils.logging - INFO - Executing remove script: FileName - FileName
# 2025-01-07 07:40:44,191 - slines.utils.logging - INFO - Executing remove script: verson - verson
# 2025-01-07 07:40:44,191 - slines.utils.logging - INFO - Executing remove script: Batch - Batch
# 2025-01-07 07:40:44,359 - slines.utils.logging - INFO - file_id: 105358473980294, file_path: 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/关于对全国和全省“八五”普法中期通报表扬单位和个人的公示.docx
# 2025-01-07 07:40:44,772 - slines.utils.logging - INFO - File exists: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/三亚市教育局关于做好2024年三亚市民办中小学校和幼儿园年检工作的通知.docx
# 2025-01-07 07:40:45,314 - slines.utils.logging - INFO - Processing file: 三亚市人民政府\政策\政府信息公开专栏\政策文件\部门文件\科技、教育;\三亚市教育局关于做好2024年三亚市民办中小学校和幼儿园年检工作的通知.docx
# 2025-01-07 07:40:45,315 - slines.utils.logging - INFO - Executing modified script fileId {'FileId': 105358480586118} -> 105358480586118
# 2025-01-07 07:40:45,317 - slines.utils.logging - INFO - Executing modified script filePath {'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\科技、教育;\\三亚市教育局关于做好2024年三亚市民办中小学校和幼儿园年检工作的通知.docx'} -> 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/三亚市教育局关于做好2024年三亚市民办中小学校和幼儿园年检工作的通知.docx
# 2025-01-07 07:40:45,318 - slines.utils.logging - INFO - Executing modified script webSite 三亚市人民政府 -> 三亚市人民政府
# 2025-01-07 07:40:45,319 - slines.utils.logging - INFO - File already uploaded: 三亚市人民政府/a94494f7c2/105358480586118
# 2025-01-07 07:40:45,320 - slines.utils.logging - INFO - Executing modified script os_id {'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/三亚市教育局关于做好2024年三亚市民办中小学校和幼儿园年检工作的通知.docx', 'webSite': '三亚市人民政府', 'fileId': 105358480586118, 'os_id': '三亚市人民政府/a94494f7c2/105358480586118'} -> 三亚市人民政府/a94494f7c2/105358480586118
# 2025-01-07 07:40:45,323 - slines.utils.logging - INFO - Executing modified script status {'GeneratedJson': None} -> 0
# 2025-01-07 07:40:45,324 - slines.utils.logging - INFO - Executing modified script isFormatted {'GeneratedJson': None} -> 0
# 2025-01-07 07:40:45,325 - slines.utils.logging - INFO - Executing modified script oldID 6650582d4726e81ab0707b1c -> 6650582d4726e81ab0707b1c
# 2025-01-07 07:40:45,325 - slines.utils.logging - INFO - Executing modified script srcUrl http://edu.sanya.gov.cn/jyjsite/bmwjxx/202404/93730b5b9af941c58afcc6893aa6e5d0.shtml -> http://edu.sanya.gov.cn/jyjsite/bmwjxx/202404/93730b5b9af941c58afcc6893aa6e5d0.shtml
# 2025-01-07 07:40:45,326 - slines.utils.logging - INFO - Executing modified script categoryList ['政策', '政府信息公开专栏', '政策文件', '部门文件', '科技、教育;'] -> ['政策', '政府信息公开专栏', '政策文件', '部门文件', '科技、教育;']
# 2025-01-07 07:40:45,327 - slines.utils.logging - INFO - Executing modified script title 三亚市教育局关于做好2024年三亚市民办中小学校和幼儿园年检工作的通知 -> 三亚市教育局关于做好2024年三亚市民办中小学校和幼儿园年检工作的通知
# 2025-01-07 07:40:45,328 - slines.utils.logging - INFO - Executing modified script releaseDate {'date_str': '2024.04.03'} -> 1712102400000
# 2025-01-07 07:40:45,329 - slines.utils.logging - INFO - Executing modified script keywordList [] -> []
# 2025-01-07 07:40:45,330 - slines.utils.logging - INFO - Executing modified script issuer 三亚市教育局 -> 三亚市教育局
# 2025-01-07 07:40:45,330 - slines.utils.logging - INFO - Executing modified script issueNo 三教基〔2024〕22号 -> 三教基〔2024〕22号
# 2025-01-07 07:40:45,331 - slines.utils.logging - INFO - Executing modified script crawlTime {'date_str': '2024-05-24T17:04:44.270000'} -> 1716570284270
# 2025-01-07 07:40:45,331 - slines.utils.logging - INFO - Executing modified script repositoryList None -> None
# 2025-01-07 07:40:45,331 - slines.utils.logging - INFO - Executing modified script levelTypeList None -> None
# 2025-01-07 07:40:45,332 - slines.utils.logging - INFO - Executing modified script accessoryList {'Accessory': ['附件1-5.doc'], 'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\科技、教育;\\三亚市教育局关于做好2024年三亚市民办中小学校和幼儿园年检工作的通知.docx'} -> ['三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/附件1-5.doc']
# 2025-01-07 07:40:45,332 - slines.utils.logging - INFO - Executing modified script attachmentList {'Attachment': [{'Name': '附件1-5.doc', 'Attachment_id': 244798951115717, 'Md5': '9be979d6c46c2e01345dfa5895b49ae2', 'Size': 364620}]} -> [{'Name': '附件1-5.doc', 'Attachment_id': 244798951115717, 'Md5': '9be979d6c46c2e01345dfa5895b49ae2', 'Size': 364620}]
# 2025-01-07 07:40:45,333 - slines.utils.logging - INFO - Executing remove script: FileId - FileId
# 2025-01-07 07:40:45,334 - slines.utils.logging - INFO - Executing remove script: SiteName - SiteName
# 2025-01-07 07:40:45,334 - slines.utils.logging - INFO - Executing remove script: Accessory - Accessory
# 2025-01-07 07:40:45,335 - slines.utils.logging - INFO - Executing remove script: FileDate - FileDate
# 2025-01-07 07:40:45,335 - slines.utils.logging - INFO - Executing remove script: CrawlTime - CrawlTime
# 2025-01-07 07:40:45,335 - slines.utils.logging - INFO - Executing remove script: Attachment - Attachment
# 2025-01-07 07:40:45,336 - slines.utils.logging - INFO - Executing remove script: Status - 删除旧的Status字段
# 2025-01-07 07:40:45,336 - slines.utils.logging - INFO - Executing remove script: GeneratedJson - 删除旧的GeneratedJson字段
# 2025-01-07 07:40:45,337 - slines.utils.logging - INFO - Executing remove script: FileName - FileName
# 2025-01-07 07:40:45,337 - slines.utils.logging - INFO - Executing remove script: verson - verson
# 2025-01-07 07:40:45,338 - slines.utils.logging - INFO - Executing remove script: Batch - Batch
# 2025-01-07 07:40:45,492 - slines.utils.logging - INFO - file_id: 105358480586118, file_path: 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/三亚市教育局关于做好2024年三亚市民办中小学校和幼儿园年检工作的通知.docx
# 2025-01-07 07:40:45,863 - slines.utils.logging - INFO - File exists: /app/remote_data/电子公文库文档数据/分类前/公司爬取数据/三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/三亚市教育局关于印发《2024年三亚市民办中小学校、幼儿园年检工作方案》的通知.docx
# 2025-01-07 07:40:46,392 - slines.utils.logging - INFO - Processing file: 三亚市人民政府\政策\政府信息公开专栏\政策文件\部门文件\科技、教育;\三亚市教育局关于印发《2024年三亚市民办中小学校、幼儿园年检工作方案》的通知.docx
# 2025-01-07 07:40:46,392 - slines.utils.logging - INFO - Executing modified script fileId {'FileId': 105358483214406} -> 105358483214406
# 2025-01-07 07:40:46,393 - slines.utils.logging - INFO - Executing modified script filePath {'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\科技、教育;\\三亚市教育局关于印发《2024年三亚市民办中小学校、幼儿园年检工作方案》的通知.docx'} -> 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/三亚市教育局关于印发《2024年三亚市民办中小学校、幼儿园年检工作方案》的通知.docx
# 2025-01-07 07:40:46,394 - slines.utils.logging - INFO - Executing modified script webSite 三亚市人民政府 -> 三亚市人民政府
# 2025-01-07 07:40:46,396 - slines.utils.logging - INFO - File already uploaded: 三亚市人民政府/d96cb086ed/105358483214406
# 2025-01-07 07:40:46,397 - slines.utils.logging - INFO - Executing modified script os_id {'filePath': '三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/三亚市教育局关于印发《2024年三亚市民办中小学校、幼儿园年检工作方案》的通知.docx', 'webSite': '三亚市人民政府', 'fileId': 105358483214406, 'os_id': '三亚市人民政府/d96cb086ed/105358483214406'} -> 三亚市人民政府/d96cb086ed/105358483214406
# 2025-01-07 07:40:46,399 - slines.utils.logging - INFO - Executing modified script status {'GeneratedJson': None} -> 0
# 2025-01-07 07:40:46,400 - slines.utils.logging - INFO - Executing modified script isFormatted {'GeneratedJson': None} -> 0
# 2025-01-07 07:40:46,400 - slines.utils.logging - INFO - Executing modified script oldID 6650582d4726e81ab0707b1d -> 6650582d4726e81ab0707b1d
# 2025-01-07 07:40:46,401 - slines.utils.logging - INFO - Executing modified script srcUrl http://edu.sanya.gov.cn/jyjsite/bmwjxx/202404/c3b4fde142434222880930a55ccb8775.shtml -> http://edu.sanya.gov.cn/jyjsite/bmwjxx/202404/c3b4fde142434222880930a55ccb8775.shtml
# 2025-01-07 07:40:46,401 - slines.utils.logging - INFO - Executing modified script categoryList ['政策', '政府信息公开专栏', '政策文件', '部门文件', '科技、教育;'] -> ['政策', '政府信息公开专栏', '政策文件', '部门文件', '科技、教育;']
# 2025-01-07 07:40:46,402 - slines.utils.logging - INFO - Executing modified script title 三亚市教育局关于印发《2024年三亚市民办中小学校、幼儿园年检工作方案》的通知 -> 三亚市教育局关于印发《2024年三亚市民办中小学校、幼儿园年检工作方案》的通知
# 2025-01-07 07:40:46,403 - slines.utils.logging - INFO - Executing modified script releaseDate {'date_str': '2024.04.03'} -> 1712102400000
# 2025-01-07 07:40:46,403 - slines.utils.logging - INFO - Executing modified script keywordList [] -> []
# 2025-01-07 07:40:46,404 - slines.utils.logging - INFO - Executing modified script issuer 三亚市教育局 -> 三亚市教育局
# 2025-01-07 07:40:46,404 - slines.utils.logging - INFO - Executing modified script issueNo 三教基〔2024〕21号 -> 三教基〔2024〕21号
# 2025-01-07 07:40:46,405 - slines.utils.logging - INFO - Executing modified script crawlTime {'date_str': '2024-05-24T17:04:45.904000'} -> 1716570285904
# 2025-01-07 07:40:46,405 - slines.utils.logging - INFO - Executing modified script repositoryList None -> None
# 2025-01-07 07:40:46,405 - slines.utils.logging - INFO - Executing modified script levelTypeList None -> None
# 2025-01-07 07:40:46,406 - slines.utils.logging - INFO - Executing modified script accessoryList {'Accessory': [], 'filename': '三亚市人民政府\\政策\\政府信息公开专栏\\政策文件\\部门文件\\科技、教育;\\三亚市教育局关于印发《2024年三亚市民办中小学校、幼儿园年检工作方案》的通知.docx'} -> []
# 2025-01-07 07:40:46,407 - slines.utils.logging - INFO - Executing modified script attachmentList {'Attachment': None} -> []
# 2025-01-07 07:40:46,408 - slines.utils.logging - INFO - Executing remove script: FileId - FileId
# 2025-01-07 07:40:46,408 - slines.utils.logging - INFO - Executing remove script: SiteName - SiteName
# 2025-01-07 07:40:46,408 - slines.utils.logging - INFO - Executing remove script: Accessory - Accessory
# 2025-01-07 07:40:46,409 - slines.utils.logging - INFO - Executing remove script: FileDate - FileDate
# 2025-01-07 07:40:46,410 - slines.utils.logging - INFO - Executing remove script: CrawlTime - CrawlTime
# 2025-01-07 07:40:46,412 - slines.utils.logging - INFO - Executing remove script: Attachment - Attachment
# 2025-01-07 07:40:46,413 - slines.utils.logging - INFO - Executing remove script: Status - 删除旧的Status字段
# 2025-01-07 07:40:46,413 - slines.utils.logging - INFO - Executing remove script: GeneratedJson - 删除旧的GeneratedJson字段
# 2025-01-07 07:40:46,414 - slines.utils.logging - INFO - Executing remove script: FileName - FileName
# 2025-01-07 07:40:46,414 - slines.utils.logging - INFO - Executing remove script: verson - verson
# 2025-01-07 07:40:46,414 - slines.utils.logging - INFO - Executing remove script: Batch - Batch
# 2025-01-07 07:40:46,682 - slines.utils.logging - INFO - file_id: 105358483214406, file_path: 三亚市人民政府/政策/政府信息公开专栏/政策文件/部门文件/科技、教育;/三亚市教育局关于印发《2024年三亚市民办中小学校、幼儿园年检工作方案》的通知.docx
# Processing complete. Total processed: 101, Success: 101, Failure: 0
